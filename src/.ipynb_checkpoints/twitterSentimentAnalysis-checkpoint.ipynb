# %%
#import necessary modules
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/train.csv",encoding='latin-1') #read the training csv 
data.head() #print f
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
# X = data['SentimentText'] #tweets
# y = data['Sentiment'] #labels

X = data['tweet'] #tweets
y = data['label'] #labels

print("Number of positive reviews: ",list(y).count(0))
print("Number of negative reviews: ",list(y).count(1))
# Out:
# Number of positive reviews:  29720
# Number of negative reviews:  2242

# %% [markdown]
# ### From the above numbers it is advent that the dataset is quite imbalanced and may affect the performance

# %%
print(X[:5])
print(y[:5])

print(X[-5:])
print(y[-5:])

#print(type(y[0]))
# Out:
# 0     @user when a father is dysfunctional and is s...
# 1    @user @user thanks for #lyft credit i can't us...
# 2                                  bihday your majesty
# 3    #model   i love u take with u all the time in ...
# 4               factsguide: society now    #motivation
# Name: tweet, dtype: object
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64
# 31957    ate @user isz that youuu?Ã°ÂÂÂÃ°ÂÂÂÃ°ÂÂ...
# 31958      to see nina turner on the airwaves trying to...
# 31959    listening to sad songs on a monday morning otw...
# 31960    @user #sikh #temple vandalised in in #calgary,...
# 31961                     thank you @user for you follow
# Name: tweet, dtype: object
# 31957    0
# 31958    0
# 31959    0
# 31960    1
# 31961    0
# Name: label, dtype: int64

# %% [markdown]
# ### A we have very small dataset its better to use single word for analysis as opposed to a single letter or whole tweet because usually positive tweets have words like "love","happy","thanks",etc.
#
# ### For this we will count a words in positive and negative reviews and find its ratio to total occurence

# %%
# We will use Counter object. It returns a dictionary of words and their count.
from collections import Counter

positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
for i in range(len(X)):
    if y[i]== 1:
        for word in X[i].split(' '):
            positive_counts[word] += 1
            total_counts[word] += 1
            
    else:
        for word in X[i].split(' '):
            negative_counts[word] += 1
            total_counts[word] += 1

# %%
positive_counts.most_common()
# Out:
# [('', 4396),
#  ('@user', 1826),
#  ('the', 816),
#  ('a', 607),
#  ('to', 561),
#  ('of', 457),
#  ('is', 425),
#  ('in', 423),
#  ('you', 394),
#  ('and', 358),
#  ('are', 314),
#  ('&amp;', 267),
#  ('for', 239),
#  ('on', 209),
#  ('be', 201),
#  ('i', 200),
#  ('this', 168),
#  ('that', 164),
#  ('Ã¢Â\x80Â¦', 160),
#  ('not', 148),
#  ('like', 131),
#  ('it', 123),
#  ('#trump', 119),
#  ('by', 117),
#  ('with', 113),
#  ('we', 106),
#  ('white', 104),
#  ('have', 103),
#  ('about', 101),
#  ('as', 94),
#  ('#politics', 94),
#  ('#allahsoil', 92),
#  ('why', 90),
#  ('what', 90),
#  ('do', 88),
#  ('your', 87),
#  ('if', 84),
#  ('so', 83),
#  ('his', 82),
#  ('but', 82),
#  ('who', 82),
#  ('-', 80),
#  ('was', 80),
#  ('all', 80),
#  ('black', 79),
#  ('might', 77),
#  ('#libtard', 76),
#  ('they', 76),
#  ('#liberal', 75),
#  ('at', 74),
#  ('#sjw', 74),
#  ('from', 74),
#  ('just', 74),
#  ('.', 73),
#  ('will', 73),
#  ('has', 72),
#  ('libtard', 72),
#  ('if...', 72),
#  ('he', 72),
#  ('no', 71),
#  ('how', 71),
#  ('my', 70),
#  ('because', 67),
#  ('people', 65),
#  ('trump', 64),
#  ('racist', 63),
#  ('against', 62),
#  ('can', 61),
#  ("don't", 60),
#  ('feel', 59),
#  ('new', 58),
#  (',', 58),
#  ('#retweet', 57),
#  ('listen', 57),
#  ('or', 55),
#  ('you?', 54),
#  ('when', 52),
#  ('an', 52),
#  ('women', 50),
#  ("it's", 49),
#  ('me', 49),
#  ('more', 48),
#  ('stomping', 48),
#  ('should', 45),
#  ('#black', 44),
#  ('being', 43),
#  ('us', 42),
#  ('up', 42),
#  ('via', 42),
#  ('one', 41),
#  ('over', 41),
#  ('her', 41),
#  ('only', 40),
#  ('out', 39),
#  ('would', 39),
#  ("i'm", 38),
#  ('racism', 38),
#  ('#miamiÃ¢Â\x80Â¦', 38),
#  ('been', 37),
#  ('2', 35),
#  ("can't", 34),
#  ('than', 34),
#  ('never', 34),
#  ('their', 34),
#  ('get', 34),
#  ('sex', 34),
#  ('our', 33),
#  ('obama', 33),
#  ('woman', 33),
#  ("you're", 33),
#  ('stop', 33),
#  ('think', 33),
#  ('#tampa', 32),
#  ('latest', 32),
#  ('good', 32),
#  ('most', 31),
#  ('comments', 31),
#  ('says', 30),
#  ('thanks', 30),
#  ('hate', 30),
#  ('video', 29),
#  ('?', 29),
#  ('#hate', 28),
#  ('#hispanic', 28),
#  ('man', 27),
#  ('.@user', 27),
#  ('say', 27),
#  ('#sikh', 27),
#  ('act', 27),
#  ('#blm', 27),
#  ('go', 27),
#  ('call', 26),
#  ('back', 26),
#  ('race', 26),
#  ('#bigot', 26),
#  ('#temple', 26),
#  ('vandalised', 26),
#  ('#calgary,', 26),
#  ('#wso', 26),
#  ('condemns', 26),
#  ('girl', 26),
#  ('after', 26),
#  ('men', 25),
#  ('#brexit', 25),
#  ('great', 25),
#  ('these', 25),
#  ('need', 24),
#  ('#malevote', 24),
#  ('look', 24),
#  ('u', 24),
#  ('see', 24),
#  ('own', 24),
#  ("isn't", 24),
#  ('#maga', 24),
#  ('suppoers', 24),
#  ('had', 24),
#  ('into', 23),
#  ('porn', 23),
#  ('fuck', 23),
#  ('still', 23),
#  ('want', 23),
#  ('many', 22),
#  ('!', 22),
#  ('its', 22),
#  ('there', 22),
#  ('please', 22),
#  ('#obama', 22),
#  ('#seashepherd', 21),
#  ('even', 21),
#  ('same', 21),
#  ('girls', 21),
#  ('let', 21),
#  ('real', 21),
#  ('other', 21),
#  ('guy', 21),
#  ('those', 21),
#  ('pay', 21),
#  ('word', 21),
#  ('she', 21),
#  ('him', 21),
#  ('#leadership', 21),
#  ('nothing', 21),
#  ('thought', 20),
#  ("that's", 20),
#  ('#feminismiscancer', 20),
#  ('#feminismisterrorism', 20),
#  ('#feminismmuktbharat', 20),
#  ('ignored', 20),
#  ('|', 20),
#  ('any', 20),
#  ('got', 20),
#  ('really', 20),
#  ('america', 20),
#  ('some', 20),
#  ('racist!', 20),
#  ('#antiracism', 20),
#  ('factory:', 20),
#  ('did', 20),
#  ('Ã¢Â\x80Â¦Ã¢Â\x80Â¦', 19),
#  ('police', 19),
#  ('also', 19),
#  ('4', 19),
#  ('sea', 19),
#  ('shepherd', 19),
#  ('make', 19),
#  ("we're", 19),
#  ('#bigotry', 18),
#  ('makes', 18),
#  ('#blacklivesmatter', 18),
#  ('daily!', 18),
#  ('keep', 18),
#  ('2016', 18),
#  ('now', 18),
#  ('president', 18),
#  ('ever', 18),
#  ('#america', 18),
#  ('must', 18),
#  ('much', 18),
#  ('time', 18),
#  ('saying', 17),
#  ('does', 17),
#  ('going', 17),
#  (':', 17),
#  ('gets', 17),
#  ('year', 17),
#  ('know', 17),
#  ("won't", 17),
#  ('2017', 17),
#  ('them', 17),
#  ('am', 16),
#  ('#altright', 16),
#  ("doesn't", 16),
#  ('take', 16),
#  ('#misogynist', 16),
#  ('every', 16),
#  ('show', 16),
#  ('#misogyny', 16),
#  ('down', 16),
#  ('where', 16),
#  ('believe', 16),
#  ('=', 16),
#  ('&amp;Ã¢Â\x80Â¦', 15),
#  ('right', 15),
#  ('#Ã¢Â\x80Â¦', 15),
#  ('first', 15),
#  ('#notmypresident', 15),
#  ('carl', 15),
#  ('school', 14),
#  ('#tcot', 14),
#  ("aren't", 14),
#  ('said', 14),
#  ('"the', 14),
#  ('end', 14),
#  ('way', 14),
#  ('#emiratis', 14),
#  ('free', 14),
#  ('#teambts', 14),
#  ('always', 14),
#  ('too', 14),
#  ('christmas', 14),
#  ('someone', 14),
#  ('use', 14),
#  ('r', 14),
#  ('...', 14),
#  ('thing', 13),
#  ('made', 13),
#  ('world', 13),
#  ('#usa', 13),
#  ('next', 13),
#  ('were', 13),
#  ('#resist', 13),
#  ('here', 13),
#  ('pa', 13),
#  ('#2017', 13),
#  ('videos', 13),
#  ('#us', 13),
#  ('then', 13),
#  ('love', 13),
#  ('kind', 13),
#  ('#putinschoice', 13),
#  ('live', 13),
#  ('off', 13),
#  ("he's", 13),
#  ('country', 13),
#  ('calls', 12),
#  ('this.', 12),
#  ('protesting', 12),
#  ('michelle', 12),
#  ('#theresistance', 12),
#  ('#white', 12),
#  ('attack', 12),
#  ('8', 12),
#  ('years', 12),
#  ('#israel', 12),
#  ('ally', 12),
#  ('muslims', 12),
#  ('#', 12),
#  ('nude', 12),
#  ('come', 12),
#  ('face', 12),
#  ('#hatred', 12),
#  ('news', 12),
#  ('#boricua', 12),
#  ('person', 12),
#  ('towards', 12),
#  ('find', 12),
#  ('ignorance', 12),
#  ('#southafrica', 12),
#  ('#boricuaÃ¢Â\x80Â¦', 12),
#  ('#teambtsÃ¢Â\x80Â¦', 12),
#  ('give', 12),
#  ('#feminism', 12),
#  ('left-right', 12),
#  ('polarisation!', 12),
#  ('#uselections2016', 12),
#  ('such', 12),
#  ('#race', 11),
#  ('#people', 11),
#  ('#republican', 11),
#  ('won-they', 11),
#  ('fuhered', 11),
#  ('remarks', 11),
#  ("i've", 11),
#  ('lost', 11),
#  ('talking', 11),
#  ('ppl', 11),
#  ('#homophobic', 11),
#  ('team', 11),
#  ('fucking', 11),
#  ('needs', 11),
#  ('#equality', 11),
#  ('white,', 11),
#  ('help', 11),
#  ('enough', 11),
#  ('history', 11),
#  ('paladino', 11),
#  ('mad', 11),
#  ('read', 11),
#  ('media', 11),
#  ('job', 11),
#  ('book', 11),
#  ('naked', 11),
#  ('it.', 11),
#  ('#love', 10),
#  ('win', 10),
#  ('#carlpaladino', 10),
#  ('speak', 10),
#  ('without', 10),
#  ('thats', 10),
#  ('happy', 10),
#  ('hope', 10),
#  ('very', 10),
#  ("didn't", 10),
#  ('dear', 10),
#  ('wish', 10),
#  ('whites', 10),
#  ('world.', 10),
#  ('#americans', 10),
#  ('called', 10),
#  ('calling', 10),
#  ('better', 10),
#  ('work', 10),
#  ('#newyork', 10),
#  ('everyone', 10),
#  ('cow', 10),
#  ("here's", 10),
#  ('Ã¢Â\x80Â\x9cwe', 10),
#  ('campaign', 10),
#  ('kkk', 10),
#  ('#kkk', 10),
#  ('#cnn', 9),
#  ('#xenophobia', 9),
#  ('voted', 9),
#  ('co-chair', 9),
#  ('american', 9),
#  ('hatred', 9),
#  ('power', 9),
#  ('while', 9),
#  ('americans', 9),
#  ('#stopracism', 9),
#  ('#2016in4words', 9),
#  ('shows', 9),
#  ('proud', 9),
#  ('children', 9),
#  ('through', 9),
#  ('well', 9),
#  ('means', 9),
#  ('fucked', 9),
#  ('#fascism', 9),
#  ('doing', 9),
#  ('#women', 9),
#  ('matter', 9),
#  ('before', 9),
#  ('another', 9),
#  ('could', 9),
#  ('reflections', 9),
#  ('male', 9),
#  ('message', 9),
#  ('may', 9),
#  ('comes', 9),
#  ('racism.', 9),
#  ('#peace', 8),
#  ('game', 8),
#  ("she's", 8),
#  ('under', 8),
#  ('talk', 8),
#  ('thank', 8),
#  ('wants', 8),
#  ('business', 8),
#  ('best', 8),
#  ('sexist', 8),
#  ('tell', 8),
#  ('mean', 8),
#  ('rest', 8),
#  ('#liar', 8),
#  ('true', 8),
#  ('Ã°Â\x9fÂ\x8cÂ\x8e', 8),
#  ('combat', 8),
#  ('equality', 8),
#  ('alt-right', 8),
#  ('hard', 8),
#  ('won', 8),
#  ('watch', 8),
#  ('disgusting', 8),
#  ('mil', 8),
#  ('rejected', 8),
#  ('#nazi', 8),
#  ('suppo', 8),
#  ('last', 8),
#  ('everything', 8),
#  ('ag', 8),
#  ('done', 8),
#  ('disease', 8),
#  ('fired', 8),
#  ('brown', 8),
#  ('anyone', 8),
#  ('again', 8),
#  ('looks', 8),
#  ('comment', 8),
#  ('aicle', 8),
#  ('reading', 8),
#  ('#islamophobia', 8),
#  ('racist.', 8),
#  ('islamic', 8),
#  ('..', 8),
#  ('ur', 8),
#  ('#donaldtrump', 8),
#  ('rights', 8),
#  ('fought', 8),
#  ('#miami', 8),
#  ('#auspol', 8),
#  ('seems', 8),
#  ('systemic', 8),
#  ("they're", 8),
#  ('racial', 8),
#  ('#traitor', 8),
#  ('n', 8),
#  ('uk', 8),
#  ('#2016in4wordsÃ¢Â\x80Â¦', 8),
#  ('trying', 8),
#  ('#emiratisÃ¢Â\x80Â¦', 8),
#  ('hey', 8),
#  ('#fascist', 8),
#  ('#2016', 7),
#  ('liberal', 7),
#  ('#discrimination', 7),
#  ('stand', 7),
#  ('evil', 7),
#  ('speaking', 7),
#  ('which', 7),
#  ('#justice', 7),
#  ('few', 7),
#  ('#new', 7),
#  ('#mc', 7),
#  ('#phillysuppophilly', 7),
#  ('problem', 7),
#  ('target', 7),
#  ('thrown', 7),
#  ('muslim', 7),
#  ('believes', 7),
#  ('nationalist', 7),
#  ('#gop', 7),
#  ('chick', 7),
#  ('#newswithed', 7),
#  ('sad', 7),
#  ('64.2', 7),
#  ('flag', 7),
#  ('big', 7),
#  ('"i', 7),
#  ('#preorder', 7),
#  ('tweet', 7),
#  ('course', 7),
#  ('change', 7),
#  ('10', 7),
#  ('abuse', 7),
#  ('shut', 7),
#  ('leave', 7),
#  ('decades', 7),
#  ('criticism', 7),
#  ('wall', 7),
#  ('goes', 7),
#  ('sick', 7),
#  ('promote', 7),
#  ('denial', 7),
#  ('#inequality', 7),
#  ('oil', 7),
#  ('#paladino', 7),
#  ('words', 7),
#  ('dangerous', 7),
#  ("#trump's", 7),
#  ('south', 7),
#  ('having', 7),
#  ('vote', 7),
#  ('htÃ¢Â\x80Â¦', 7),
#  ('#media', 7),
#  ('#teamsuperjunior', 7),
#  ('wishes', 7),
#  ('/', 7),
#  ('3', 7),
#  ('industry', 7),
#  ('islam', 7),
#  ('swiftly', 7),
#  ('sharpens', 7),
#  ('fang', 7),
#  ('#hillary', 7),
#  ('both', 7),
#  ('today', 7),
#  ('response', 7),
#  ("america's", 7),
#  ('death', 7),
#  ('play', 7),
#  ('bit', 7),
#  ('#jeffsessions', 7),
#  ('#msnbc', 7),
#  ('maybe', 7),
#  ('#australia', 6),
#  ('#neverump', 6),
#  ('fight', 6),
#  ('themselves', 6),
#  ('#whitesupremacy', 6),
#  ('#michelleobama', 6),
#  ('long', 6),
#  ('times', 6),
#  ('#antisemitism', 6),
#  ('ny', 6),
#  ('#p2', 6),
#  ('troll', 6),
#  ('african', 6),
#  ('#whitepeople', 6),
#  ('ignorant', 6),
#  ('used', 6),
#  ('telling', 6),
#  ('allowed', 6),
#  ('rape', 6),
#  ('opposition', 6),
#  ('small', 6),
#  ('im', 6),
#  ('asian', 6),
#  ('yet', 6),
#  ('donkey', 6),
#  ('murdering', 6),
#  ('palestinian', 6),
#  ('semitic', 6),
#  ('#humanrights', 6),
#  ('kids', 6),
#  ('pussy', 6),
#  ('different', 6),
#  ('claims', 6),
#  ('land', 6),
#  ('lying', 6),
#  ('government', 6),
#  ('meant', 6),
#  ('#fear', 6),
#  ('#christians', 6),
#  ('vs.', 6),
#  ('check', 6),
#  ('less', 6),
#  ('to.', 6),
#  ('#dystopian', 6),
#  ('far', 6),
#  ('marijuana', 6),
#  ('unleashed', 6),
#  ('ibooks.', 6),
#  ('shit', 6),
#  ('lady', 6),
#  ('#retweetÃ¢Â\x80Â¦', 6),
#  ('#men', 6),
#  ('officers', 6),
#  ('total', 6),
#  ('ask', 6),
#  ('#police', 6),
#  ('jeff', 6),
#  ('sessions', 6),
#  ('send', 6),
#  ('join', 6),
#  ('#truth', 6),
#  ('#fakenews', 6),
#  ('color', 6),
#  ('blm', 6),
#  ('prevents', 6),
#  ('healing!', 6),
#  ('#transformation', 6),
#  ('hand', 6),
#  ('spread', 6),
#  ('lives', 6),
#  ('day', 6),
#  ('impression', 6),
#  ('accept', 6),
#  ('#boycott?Ã¢Â\x80Â¦', 6),
#  ('close', 6),
#  ('originally', 6),
#  ('extremism', 6),
#  ('racism,', 6),
#  ('wait', 6),
#  ('#putinspuppet', 6),
#  ("ain't", 6),
#  ('war', 6),
#  ('oil.', 6),
#  ('fat', 6),
#  ('music', 6),
#  ('given', 6),
#  ('jokes', 6),
#  ('+', 6),
#  ('jew', 6),
#  ('deal', 6),
#  ('post', 6),
#  ('#history', 6),
#  ('left', 6),
#  ('thinks', 6),
#  ('#lgbt', 6),
#  ('ass', 6),
#  ('miss', 6),
#  ('realize', 6),
#  ('list', 6),
#  ('blicqerÃ¢Â\x84Â¢', 6),
#  ('stories', 6),
#  ('already', 6),
#  ('destroy', 6),
#  ('#rape', 6),
#  ('#povey', 6),
#  ('hot', 6),
#  ('#environmental', 6),
#  ('lot', 6),
#  ('around', 5),
#  ('yes', 5),
#  ('point', 5),
#  ('open', 5),
#  ('try', 5),
#  ('#hope', 5),
#  ('old', 5),
#  ('hateful', 5),
#  ('#potus', 5),
#  ('woh', 5),
#  ('become', 5),
#  ('sexy', 5),
#  ('coming', 5),
#  ('openly', 5),
#  ('kid', 5),
#  ('no,', 5),
#  ('wear', 5),
#  ('#slavery', 5),
#  ('#apaheid', 5),
#  ('past', 5),
#  ('#tedtalks', 5),
#  ('non', 5),
#  ('disappointed', 5),
#  ("i'd", 5),
#  ('worst', 5),
#  ('together', 5),
#  ('are.', 5),
#  ('buffalo', 5),
#  ('buy', 5),
#  ('s', 5),
#  ('shot', 5),
#  ('office', 5),
#  ('age', 5),
#  ('caused', 5),
#  ('thereÃ¢Â\x80Â\x99s', 5),
#  ('issue', 5),
#  ('whÃ¢Â\x80Â¦', 5),
#  ('b', 5),
#  ('#japan', 5),
#  ('#bbc', 5),
#  ('white.', 5),
#  ('w/o', 5),
#  ("women's", 5),
#  ('fire', 5),
#  ('dumb', 5),
#  ('silence', 5),
#  ('stupid', 5),
#  ('fly', 5),
#  ('half', 5),
#  ('#trumpsamerica', 5),
#  ('#hateful', 5),
#  ('serve', 5),
#  ("let's", 5),
#  ('#teamsuperjuniorÃ¢Â\x80Â¦', 5),
#  ('tale', 5),
#  ('#radicalisation', 5),
#  ('#revenge', 5),
#  ('me.', 5),
#  ('following', 5),
#  ('violent', 5),
#  ('denounce', 5),
#  ('jews', 5),
#  ('#bigots', 5),
#  ('market', 5),
#  ('until', 5),
#  ('son', 5),
#  ('either', 5),
#  ('profiling', 5),
#  ('hearing', 5),
#  ('board', 5),
#  ('#obamas', 5),
#  ('members', 5),
#  ('others', 5),
#  ('#treason', 5),
#  ('#fraud', 5),
#  ('#unpresidented', 5),
#  ('#adultery', 5),
#  ('#incest', 5),
#  ('reveals', 5),
#  ('5', 5),
#  ('plz', 5),
#  ('little', 5),
#  ('lol', 5),
#  ('boys', 5),
#  ('peopleÃ¢Â\x80Â\x9d', 5),
#  ('landholding', 5),
#  ('males.Ã¢Â\x80Â\x9d', 5),
#  ('obamas', 5),
#  ('@', 5),
#  ('kill', 5),
#  ('itÃ¢Â\x80Â\x99s', 5),
#  ('#russia', 5),
#  ('life', 5),
#  ('class', 5),
#  ('him.', 5),
#  ('mother', 5),
#  ('mt', 5),
#  ("men's", 5),
#  ('wife', 5),
#  ('#education', 5),
#  ('pick', 5),
#  ('forget', 5),
#  ('men.', 5),
#  ("who's", 5),
#  ('#hatecrime', 5),
#  ('#rwnj', 5),
#  ('aÃ¢Â\x80Â¦', 5),
#  ('staff', 5),
#  ('came', 5),
#  ('deaths', 5),
#  ('strong', 5),
#  ('case', 5),
#  ('gonna', 5),
#  ('anything', 5),
#  ('twitter', 5),
#  ('answer', 5),
#  ('blacks', 5),
#  ('claim', 5),
#  ('#whiteprivilege', 5),
#  ('all.', 5),
#  ('w/', 5),
#  ('dare', 5),
#  ('yourself', 5),
#  ('policies', 5),
#  ('single', 5),
#  ('million', 5),
#  ('church', 5),
#  ('stands', 5),
#  ('jews,', 5),
#  ('#religion', 5),
#  (')', 5),
#  ('flight', 5),
#  ('joke', 5),
#  ('wrong', 5),
#  ('israeli', 5),
#  ('women.', 5),
#  ('gender', 5),
#  ('surprised', 5),
#  ('cnn', 5),
#  ('oh', 5),
#  ('follow', 5),
#  ('present', 5),
#  ('bad', 5),
#  ('#zionism', 5),
#  ('form', 5),
#  ('surprise', 5),
#  ('#sexualpredator', 5),
#  ('b/c', 5),
#  ('perhaps', 5),
#  ('discrimination', 5),
#  ('term', 5),
#  ('buddy', 5),
#  ('once', 5),
#  ('reality', 5),
#  ('donald', 5),
#  ("'", 5),
#  ('christians', 5),
#  ('blatant', 5),
#  ('main', 5),
#  ('street', 5),
#  ('acts', 5),
#  ('#freemilo', 5),
#  ('again.', 4),
#  ('running', 4),
#  ('loving', 4),
#  ('promoting', 4),
#  ('racists', 4),
#  ('millions', 4),
#  ('state', 4),
#  ('#hatred,', 4),
#  ('found', 4),
#  ('wÃ¢Â\x80Â¦', 4),
#  ('young', 4),
#  ('Ã¢Â\x80Â\x93', 4),
#  ('absolutely', 4),
#  ('fo', 4),
#  ('officer', 4),
#  ('ignore', 4),
#  ('anti', 4),
#  ('africa', 4),
#  ('things', 4),
#  ('vids', 4),
#  ('evidence', 4),
#  ('company', 4),
#  ('keeps', 4),
#  ('family', 4),
#  ('Ã°Â\x9fÂ\x98Â\x92', 4),
#  ('guess', 4),
#  ('lack', 4),
#  ('it,', 4),
#  ('entire', 4),
#  ('whilst', 4),
#  ('week', 4),
#  ('#trumpusa', 4),
#  ('jealous', 4),
#  ('#endof2016', 4),
#  ('based', 4),
#  ('#isis', 4),
#  ('bc', 4),
#  ('judge', 4),
#  ('#raÃ¢Â\x80Â¦', 4),
#  ('callÃ¢Â\x80Â¦', 4),
#  ('rid', 4),
#  ('theÃ¢Â\x80Â¦', 4),
#  ('gay', 4),
#  ('suppoing', 4),
#  ('#democraticpay', 4),
#  ('#liberals', 4),
#  ('care', 4),
#  ('logic', 4),
#  ('#feminist', 4),
#  ('#hillaryclinton', 4),
#  ('wanna', 4),
#  ('id', 4),
#  ('god', 4),
#  ('#rohingya', 4),
#  ('names', 4),
#  ('teen', 4),
#  ('agree', 4),
#  ('wouldnÃ¢Â\x80Â\x99t', 4),
#  ('renowned', 4),
#  ('#genocide', 4),
#  ('within', 4),
#  ('seriously', 4),
#  ('seen', 4),
#  ('fans', 4),
#  ('mast', 4),
#  ('jan.Ã¢Â\x80Â¦', 4),
#  ('#asian', 4),
#  ('minority', 4),
#  ('each', 4),
#  ('public', 4),
#  ('revolution', 4),
#  ('#ris2016', 4),
#  ('#antiblackness', 4),
#  ('#zionazis', 4),
#  ('#trumpism', 4),
#  ('happened', 4),
#  ('#corruption', 4),
#  ('#terrorism', 4),
#  ('clearly', 4),
#  ('#ignorance', 4),
#  ('self', 4),
#  ('out!', 4),
#  ('service', 4),
#  ('idea', 4),
#  ('making', 4),
#  ('eu', 4),
#  ('xians', 4),
#  ('money', 4),
#  ('stay', 4),
#  ('#podcast', 4),
#  ('#muslim', 4),
#  ('#science', 4),
#  ('abt', 4),
#  ('fear', 4),
#  ('#harassment', 4),
#  ('omits', 4),
#  ('records', 4),
#  ('confirmation', 4),
#  ('trumps', 4),
#  ('#audiblechannels', 4),
#  ('genetics?', 4),
#  ('speech', 4),
#  ('#resistance', 4),
#  ('excellent', 4),
#  ('deep', 4),
#  ('hang', 4),
#  ('opposed', 4),
#  ('obama.', 4),
#  ('#notmypres', 4),
#  ('bearÃ¢Â\x80Â\x99s', 4),
#  ('rapacious', 4),
#  ('hunger', 4),
#  ('sealed', 4),
#  ('doom.', 4),
#  ('#resign', 4),
#  ('"black', 4),
#  ('definition', 4),
#  ('piece', 4),
#  ('schools', 4),
#  ('horrifying', 4),
#  ('hopes', 4),
#  ('york', 4),
#  ('dad', 4),
#  ('hillary', 4),
#  ('truth', 4),
#  ('liberals', 4),
#  ('working', 4),
#  ('boy', 4),
#  ('share', 4),
#  ('wow', 4),
#  ('balls', 4),
#  ('expose', 4),
#  ('whole', 4),
#  ('official', 4),
#  ('teach', 4),
#  ('enemies', 4),
#  ('so.', 4),
#  ('declared', 4),
#  ('winner?', 4),
#  ('#swastika', 4),
#  ('write', 4),
#  ('truly', 4),
#  ('none', 4),
#  ('gone', 4),
#  ('da', 4),
#  ('cold', 4),
#  ('#jcpenny', 4),
#  ('dead', 4),
#  ('quit', 4),
#  ('hood', 4),
#  ('yrs', 4),
#  ('#lies', 4),
#  ('practice', 4),
#  ('#policebrutality', 4),
#  ('america:', 4),
#  ('alive', 4),
#  ('ends', 4),
#  ('hopeful', 4),
#  ('council', 4),
#  ('#newyearseve', 4),
#  ('so,', 4),
#  ('trump.', 4),
#  ('regarding', 4),
#  ('httÃ¢Â\x80Â¦', 4),
#  ('blamed', 4),
#  ('unifying', 4),
#  ('force.', 4),
#  ('hated', 4),
#  ('#palestine', 4),
#  ('too.', 4),
#  ('#rapist', 4),
#  ('full', 4),
#  ('#nazis', 4),
#  ('this?', 4),
#  ('especially', 4),
#  ('Ã¢Â\x80Â¦on', 4),
#  ('#newyorkÃ¢Â\x80Â¦', 4),
#  ('Ã°Â\x9fÂ¤Â\x94', 4),
#  ('fair', 4),
#  ('jewish', 4),
#  ('wonder', 4),
#  ('voters', 4),
#  ('guilty', 4),
#  ('treason', 4),
#  ('looking', 4),
#  ('arabic', 4),
#  ('#tlot', 4),
#  ('(@user', 4),
#  ('explain', 4),
#  ('#moron', 4),
#  ('below', 4),
#  ("paladino's", 4),
#  ('spark', 4),
#  ('#mtv', 4),
#  ('welcome', 4),
#  ...]

# %%
negative_counts.most_common()
# Out:
# [('', 88534),
#  ('@user', 15465),
#  ('the', 9249),
#  ('to', 9196),
#  ('a', 5653),
#  ('i', 5455),
#  ('you', 4555),
#  ('and', 4473),
#  ('for', 4196),
#  ('in', 4147),
#  ('of', 3695),
#  ('is', 3677),
#  ('my', 3556),
#  ('with', 2369),
#  ('on', 2344),
#  ('this', 2294),
#  ('be', 2172),
#  ('it', 1977),
#  ('so', 1805),
#  ('all', 1743),
#  ('that', 1593),
#  ('your', 1584),
#  ('at', 1540),
#  ('have', 1503),
#  ('are', 1488),
#  ('day', 1448),
#  ('#love', 1439),
#  ('happy', 1318),
#  ('&amp;', 1307),
#  ('just', 1256),
#  ('when', 1181),
#  ('will', 1177),
#  ('-', 1162),
#  ('we', 1159),
#  ('me', 1148),
#  ('am', 1138),
#  ('love', 1099),
#  ('u', 1092),
#  ('not', 1005),
#  ("it's", 983),
#  ('from', 965),
#  ('but', 965),
#  ("i'm", 953),
#  ('what', 918),
#  ('time', 900),
#  ('#positive', 870),
#  ('get', 869),
#  ('new', 844),
#  ('as', 821),
#  ('our', 819),
#  ('was', 803),
#  ('.', 798),
#  ('like', 789),
#  ('do', 784),
#  ('out', 769),
#  ('how', 754),
#  ('Ã¢Â\x80Â¦', 745),
#  ('about', 730),
#  ('now', 728),
#  ('by', 710),
#  ('see', 708),
#  ('good', 702),
#  ("can't", 693),
#  ('can', 674),
#  ('!', 665),
#  ('up', 660),
#  ('one', 646),
#  ('no', 645),
#  ('@', 629),
#  ('they', 628),
#  ('people', 622),
#  ('more', 603),
#  ('want', 592),
#  ('take', 590),
#  ("don't", 564),
#  ('#healthy', 556),
#  ('today', 539),
#  ('if', 529),
#  ('an', 518),
#  ('go', 518),
#  ('#smile', 514),
#  ('make', 510),
#  ('who', 506),
#  ('bihday', 504),
#  ('bull', 504),
#  ('life', 499),
#  ('got', 498),
#  ('has', 493),
#  ('or', 478),
#  ('need', 476),
#  ('#thankful', 464),
#  ('going', 453),
#  ('thankful', 450),
#  ('!!', 448),
#  ('only', 438),
#  ('best', 438),
#  ('their', 434),
#  ('first', 433),
#  ('really', 425),
#  ('great', 421),
#  ('his', 417),
#  ('2', 416),
#  ('he', 413),
#  ('#fun', 410),
#  ('some', 406),
#  ('very', 400),
#  ('way', 397),
#  ('been', 393),
#  ('wait', 386),
#  ('#life', 376),
#  ('know', 369),
#  ('#affirmation', 362),
#  ('there', 361),
#  ('#model', 360),
#  ("father's", 359),
#  ('back', 356),
#  ('days', 353),
#  ('after', 350),
#  ('#blog', 343),
#  ('being', 342),
#  ('never', 341),
#  ('think', 340),
#  ('#summer', 340),
#  ('#cute', 339),
#  ('us', 334),
#  ('why', 327),
#  ('urÃ°Â\x9fÂ\x93Â±!!!', 325),
#  ('Ã°Â\x9fÂ\x98Â\x99Ã°Â\x9fÂ\x98Â\x8eÃ°Â\x9fÂ\x91Â\x84Ã°Â\x9fÂ\x91Â\x85Ã°Â\x9fÂ\x92Â¦Ã°Â\x9fÂ\x92Â¦Ã°Â\x9fÂ\x92Â¦',
#   325),
#  ('her', 325),
#  ('had', 324),
#  ('last', 319),
#  ('off', 318),
#  ('work', 316),
#  ('#me', 314),
#  ('even', 314),
#  ('Ã¢Â\x86Â\x9d', 309),
#  ('#fathersday', 306),
#  ('feel', 306),
#  ('#i_am', 304),
#  ('...', 304),
#  ("you're", 300),
#  ('#silver', 299),
#  ('next', 298),
#  ('much', 298),
#  ('always', 298),
#  ('#gold', 297),
#  ('finally', 297),
#  (':)', 295),
#  (',', 293),
#  ('still', 292),
#  ('week', 292),
#  ('than', 288),
#  ('find', 287),
#  ('right', 286),
#  ('thank', 283),
#  ('come', 281),
#  ('these', 281),
#  ('#altwaystoheal', 272),
#  ('too', 269),
#  ('morning', 268),
#  ('#beautiful', 268),
#  ('makes', 267),
#  ('#forex', 265),
#  ('things', 265),
#  ('tomorrow', 264),
#  ('do.', 264),
#  ('#bihday', 264),
#  ('looking', 262),
#  ('#music', 262),
#  ('because', 261),
#  ('here', 259),
#  ('sad', 257),
#  ('many', 257),
#  ('getting', 254),
#  ('#family', 254),
#  ('over', 251),
#  ('ready', 249),
#  ('them', 248),
#  ('little', 248),
#  ('then', 248),
#  ('she', 247),
#  ('look', 244),
#  ('#selfie', 241),
#  ('world', 240),
#  ('#weekend', 239),
#  ('another', 238),
#  ('#friends', 236),
#  ('4', 234),
#  ('via', 233),
#  ('night', 233),
#  ('bear', 229),
#  ('old', 228),
#  ('its', 227),
#  ('thanks', 224),
#  ('whatever', 224),
#  ('weekend', 223),
#  ('#orlando', 220),
#  ('#happiness', 219),
#  ('live', 218),
#  ('year', 216),
#  ('polar', 216),
#  ('watch', 214),
#  ('would', 213),
#  ('feeling', 212),
#  ('sta', 209),
#  ('every', 208),
#  ('most', 208),
#  ('day!', 208),
#  ('#day', 207),
#  ('beautiful', 206),
#  ('made', 203),
#  ('fathers', 203),
#  ('#friday', 202),
#  ('1', 201),
#  ('should', 200),
#  ('amazing', 199),
#  ('friday', 197),
#  ('having', 196),
#  ('#instagood', 193),
#  ('climb', 193),
#  ("i've", 190),
#  ('home', 190),
#  ('say', 189),
#  ('3', 188),
#  ('until', 187),
#  ('may', 186),
#  ('#blessed', 186),
#  ('before', 185),
#  ('show', 185),
#  ('keep', 184),
#  ('family', 183),
#  ('coming', 183),
#  ('down', 182),
#  ('him', 181),
#  ('where', 180),
#  ('well', 179),
#  ('someone', 179),
#  ('direct', 178),
#  ('stop', 178),
#  ('hope', 178),
#  ('found', 178),
#  ('into', 176),
#  ('any', 176),
#  ('around', 175),
#  ('up:', 175),
#  ('dominate', 175),
#  ('everyone', 174),
#  ('sunday', 173),
#  ('angry', 171),
#  ('ever', 171),
#  ('did', 169),
#  ('let', 168),
#  ('game', 168),
#  ('help', 168),
#  ('were', 167),
#  ("that's", 166),
#  (':', 166),
#  ('#', 165),
#  ('follow', 165),
#  ('#motivation', 164),
#  ('excited', 164),
#  ('long', 164),
#  ('friends', 164),
#  ('big', 163),
#  ('man', 163),
#  ('tonight', 162),
#  ('two', 161),
#  ('city.', 161),
#  ('n', 159),
#  ('#sun', 159),
#  ('such', 159),
#  ('god', 156),
#  ('#quote', 155),
#  ('miss', 154),
#  ('watching', 154),
#  ('forward', 153),
#  ('without', 153),
#  ('something', 152),
#  ('#grateful', 152),
#  ('#peace', 152),
#  ('bing', 151),
#  ('believe', 151),
#  ('free', 150),
#  ('#sunday', 150),
#  ('waiting', 150),
#  ('bong', 150),
#  ('better', 149),
#  ('?', 148),
#  ('playing', 147),
#  ('it.', 147),
#  ('nothing', 147),
#  ('summer', 147),
#  ('#photooftheday', 146),
#  ('other', 146),
#  ('might', 145),
#  ('girl', 145),
#  ('music', 144),
#  ('#work', 142),
#  ('#followme', 142),
#  ('check', 140),
#  ('Ã°Â\x9fÂ\x98Â\x8a', 139),
#  ('those', 138),
#  ("didn't", 138),
#  ('again', 136),
#  ('could', 136),
#  ('#girl', 135),
#  ('#funny', 135),
#  ('Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8f', 134),
#  ('gonna', 134),
#  ('years', 134),
#  ('bad', 134),
#  ('doing', 134),
#  ('give', 134),
#  ('please', 133),
#  ('"', 131),
#  ('hea', 129),
#  ("we're", 129),
#  ('own', 129),
#  ('dad', 129),
#  ('wish', 129),
#  ('today.', 128),
#  ('attack', 128),
#  ('making', 128),
#  ('lost', 127),
#  ('#fashion', 127),
#  ('weeks', 127),
#  ('friend', 126),
#  ('#dog', 126),
#  ('#a', 126),
#  ("i'll", 125),
#  ('pay', 124),
#  ('#euro2016', 124),
#  ('nice', 124),
#  ('thing', 124),
#  ('#tbt', 124),
#  ('smile', 124),
#  ('buffalo', 124),
#  ('day.', 123),
#  ('orlando', 123),
#  ('guys', 123),
#  ('hate', 123),
#  ('news', 123),
#  ('left', 123),
#  ('im', 122),
#  ('done', 122),
#  ('oh', 122),
#  ('tear', 122),
#  ('ur', 121),
#  ('+', 121),
#  ('looks', 120),
#  (':(', 120),
#  ('Ã°Â\x9fÂ\x98Â\x8d', 120),
#  ('play', 120),
#  ('enjoy', 119),
#  ('living', 119),
#  ('&lt;3', 119),
#  ('leave', 119),
#  ('gorilla', 119),
#  ('lot', 119),
#  ('lovely', 118),
#  ('|', 118),
#  ('real', 118),
#  ('place', 117),
#  ('kids', 116),
#  ('#travel', 116),
#  ('end', 116),
#  ("doesn't", 116),
#  ('few', 115),
#  ('#home', 115),
#  ('5', 114),
#  ('environment.', 114),
#  ('strong', 114),
#  ('does', 113),
#  ('away', 112),
#  ('simulator:', 112),
#  ('adapt', 112),
#  ('yeah', 111),
#  ('everything', 111),
#  ('#wedding', 111),
#  ('happiness', 111),
#  ('#dad', 111),
#  ('full', 111),
#  ('person', 110),
#  ('try', 110),
#  ('each', 109),
#  ('r', 109),
#  ('stay', 109),
#  ('today!', 109),
#  ('simulation:', 109),
#  ('#beach', 109),
#  ('food', 108),
#  ('baby', 108),
#  ('#happy', 108),
#  ('school', 107),
#  ('lol', 107),
#  ('fun', 107),
#  ('team', 106),
#  ('.@user', 106),
#  ('!!!', 106),
#  ('girls', 105),
#  ('x', 105),
#  ('#holiday', 105),
#  ('#food', 105),
#  ('father', 104),
#  ('hard', 104),
#  ('pa', 104),
#  ('#cool', 104),
#  ('saturday', 104),
#  ('#healing', 104),
#  ('since', 104),
#  ('trump', 103),
#  ('head', 103),
#  ('#hot', 103),
#  ('which', 102),
#  ('#inspiration', 102),
#  ('same', 99),
#  ('#enjoy', 99),
#  ('it!', 98),
#  ('while', 98),
#  ('me.', 98),
#  ('till', 98),
#  ('change', 98),
#  ("he's", 98),
#  ("what's", 98),
#  ('#girls', 97),
#  ('seeing', 97),
#  ('soon', 97),
#  ('you.', 96),
#  ('Ã¢Â\x80Â\x93', 96),
#  ('poetry', 96),
#  ('put', 95),
#  ('meet', 95),
#  ('hear', 95),
#  ('awesome', 95),
#  ('yet', 95),
#  ('buy', 95),
#  ('working', 94),
#  ('already', 94),
#  ('thought', 94),
#  ('through', 93),
#  ('must', 93),
#  ("won't", 92),
#  ('cold', 92),
#  ('said', 92),
#  ('#fitness', 92),
#  ('#follow', 92),
#  ('super', 91),
#  ('Ã°Â\x9fÂ\x98Â\x82', 91),
#  ('read', 91),
#  ('#quotes', 90),
#  ('wonderful', 90),
#  ('video', 90),
#  ('..', 90),
#  ('face', 90),
#  ('use', 89),
#  ('sex', 89),
#  ('#rip', 89),
#  ('Ã°Â\x9fÂ\x98Â\x94', 89),
#  ('house', 89),
#  ('came', 89),
#  ('#success', 88),
#  ('comes', 88),
#  ('trying', 88),
#  ('says', 88),
#  ('season', 88),
#  ('almost', 88),
#  ('#prayfororlando', 87),
#  ('delete', 87),
#  ('yes', 86),
#  ('#sexy', 86),
#  ('useful', 86),
#  ('#pay', 86),
#  ('black', 85),
#  ('#amazing', 85),
#  ('song', 85),
#  ('tell', 85),
#  ('tweets!', 85),
#  ('shooting', 84),
#  ('saw', 84),
#  ('yourself', 84),
#  ('june', 84),
#  ('#free', 84),
#  ('job', 84),
#  ('well:', 84),
#  ('book', 83),
#  ('aww', 83),
#  ('actually', 83),
#  ('Ã°Â\x9fÂ\x98Â\x81', 83),
#  ('#deletetweets', 83),
#  ('hours', 82),
#  ('empty', 82),
#  ('rest', 82),
#  ('loved', 82),
#  ('both', 82),
#  ('moment', 82),
#  ('join', 82),
#  ('hardcore', 82),
#  ('you,', 81),
#  ('2016', 81),
#  ('shit', 81),
#  ('also', 81),
#  ('sleep', 81),
#  ('places', 80),
#  ('side', 80),
#  ('twitter', 80),
#  ('true', 80),
#  ('#saturday', 80),
#  ("isn't", 80),
#  ('went', 79),
#  ('goes', 79),
#  ('#proud', 79),
#  ('ppl', 79),
#  ('#joy', 78),
#  ('tickets', 78),
#  ('month', 78),
#  ('open', 77),
#  ('times', 77),
#  ('mind', 77),
#  ('kind', 77),
#  ('care', 77),
#  ('perfect', 77),
#  ('anything', 77),
#  ('#health', 77),
#  ('1st', 77),
#  ('you!', 76),
#  ('hour', 76),
#  ('#goodmorning', 76),
#  ('7', 76),
#  ('#tgif', 75),
#  ('#baby', 75),
#  ('#mindset', 74),
#  ('fact', 74),
#  ('needs', 74),
#  ('fuck', 74),
#  ("let's", 74),
#  ('10', 74),
#  ('#beauty', 74),
#  ('pretty', 73),
#  ('visit', 73),
#  ('myself', 73),
#  ('life.', 73),
#  ('gone', 73),
#  ('top.tags', 73),
#  ('#photography', 73),
#  ('monday', 72),
#  ('sure', 72),
#  ('Ã°Â\x9fÂ\x98Â¢', 72),
#  ('leads', 71),
#  ('racing:', 71),
#  ('racing,', 71),
#  ('anyone', 71),
#  ('complete', 71),
#  ('able', 71),
#  ('#lifestyle', 71),
#  ('thoughts', 71),
#  ('win', 71),
#  ('now.', 70),
#  ('proud', 70),
#  ('hey', 70),
#  ('#2016', 70),
#  ('#like', 70),
#  ('#nervous', 70),
#  ('call', 70),
#  ('gun', 69),
#  ('high', 69),
#  ('#live', 69),
#  ('others', 69),
#  ('money', 69),
#  ('#london', 69),
#  ('fathersday', 69),
#  ('under', 69),
#  ('dead', 69),
#  ('couple', 68),
#  ('#relax', 68),
#  ('6', 68),
#  ('omg', 68),
#  ('young', 68),
#  ('favorite', 68),
#  ('dog', 68),
#  ('organizations', 67),
#  ('loving', 67),
#  ('here:', 67),
#  ('else', 67),
#  ('stas', 67),
#  ('#nature', 67),
#  ('sometimes', 66),
#  ('#sad', 66),
#  ('#hair', 66),
#  ('#friend', 66),
#  ('special', 66),
#  ('remember', 66),
#  ('#morning', 66),
#  ('Ã°Â\x9fÂ\x98Â\x80', 65),
#  ('culture-of-development', 65),
#  ('far', 65),
#  ('impoant', 65),
#  ('reached', 65),
#  ('dont', 65),
#  ('guy', 65),
#  ('#anxiety', 65),
#  ('less', 65),
#  ('whole', 65),
#  ("there's", 65),
#  ('post', 65),
#  ('#shop', 64),
#  ('beach', 64),
#  ('enough', 64),
#  ('fans', 64),
#  ('lives', 64),
#  (':d', 64),
#  ('cause', 63),
#  ('mom', 63),
#  ('#fathers', 63),
#  ('power', 63),
#  ('=', 63),
#  ('country', 63),
#  ('happened', 63),
#  ('Ã°Â\x9fÂ\x92Â\x95', 63),
#  ('cant', 63),
#  ('guess', 63),
#  ('#flowers', 63),
#  ('homes', 63),
#  ('#awesome', 63),
#  ('staing', 63),
#  ('trip', 63),
#  ('#picoftheday', 63),
#  ('Ã°Â\x9fÂ\x94Â\x9d', 63),
#  ('early', 63),
#  ('mindset', 62),
#  ('boy', 62),
#  ('months', 62),
#  ('#depressed', 62),
#  ('talk', 62),
#  ('Ã°Â\x9fÂ\x98Â\x98', 62),
#  ('#father', 62),
#  ('despite', 62),
#  ('set', 62),
#  ('against', 62),
#  ("today's", 62),
#  ('once', 61),
#  ('d', 61),
#  ('wedding', 61),
#  ('cannot', 61),
#  ('taking', 61),
#  ('gift', 61),
#  ('women', 61),
#  ('bed', 61),
#  ('day,', 60),
#  ('Ã¢Â\x9dÂ¤', 60),
#  ('words', 60),
#  ('y', 60),
#  ('#nude', 60),
#  ('#today', 60),
#  ('wrong', 60),
#  ('children', 60),
#  ('matter', 60),
#  ('vicinity', 60),
#  ('#cantwait', 60),
#  ('seen', 60),
#  ('tweet', 60),
#  ('wishing', 59),
#  ('b', 59),
#  ('happy.', 59),
#  ('#affirmations', 59),
#  ('run', 59),
#  ('#gay', 59),
#  ('hill', 59),
#  ('Ã°Â\x9fÂ\x98Â\x84', 59),
#  ('story', 59),
#  ('america', 58),
#  ('#new', 58),
#  ('target', 58),
#  ('#smiles', 57),
#  ('bring', 57),
#  ('seems', 57),
#  ('understand', 57),
#  ('fucking', 57),
#  ('#porn', 57),
#  ("they're", 57),
#  ('reach', 57),
#  ('time.', 56),
#  ('gbp', 56),
#  ('update', 56),
#  ('hair', 56),
#  ('#lawofattraction', 56),
#  ('#monday', 56),
#  ('2nd', 56),
#  ('movie', 56),
#  ('dream', 56),
#  ('dads', 56),
#  ('#sunshine', 56),
#  ('#Ã¢Â\x80Â¦', 56),
#  ('order', 56),
#  ('~', 56),
#  ('#lighttherapy', 56),
#  ('#kids', 56),
#  ('#orlandoshooting', 55),
#  ('prayers', 55),
#  ('#cat', 55),
#  ('heard', 55),
#  ('htÃ¢Â\x80Â¦', 55),
#  ('booked', 55),
#  ('w/', 55),
#  ('httÃ¢Â\x80Â¦', 55),
#  ('#depression?', 55),
#  ('#lgbt', 55),
#  ('cool', 55),
#  ('birds', 54),
#  ('date', 54),
#  ('victims', 54),
#  ('close', 54),
#  ('choose', 54),
#  ('used', 54),
#  ('#good', 54),
#  ('#photo', 54),
#  ('least', 54),
#  ('single', 54),
#  ('officially', 54),
#  ('yo', 54),
#  ('together', 54),
#  ('gets', 53),
#  ('finding', 53),
#  ('half', 53),
#  ('enjoying', 53),
#  ("haven't", 53),
#  ('become', 53),
#  ('wanted', 53),
#  ('task', 53),
#  ('way,', 53),
#  ('mean', 53),
#  ('killed', 53),
#  ('feels', 53),
#  ('holiday', 53),
#  ('finished', 53),
#  ('media', 53),
#  ('#depression', 53),
#  ('tomorrow.', 53),
#  ('wanna', 53),
#  ('50', 52),
#  ("you've", 52),
#  ('#dance', 52),
#  ('(vine', 52),
#  ('3d:', 52),
#  ('Ã¢Â\x80Â\x94', 52),
#  ('episode', 52),
#  ('city', 52),
#  ('wow', 52),
#  ('#young', 52),
#  ('send', 52),
#  ('#loveÃ¢Â\x80Â¦', 52),
#  ('climb:', 52),
#  ('survive.', 52),
#  ('sorry', 52),
#  ('wake', 52),
#  ('talking', 51),
#  ('hit', 51),
#  ('conference:', 51),
#  ('#thursday', 51),
#  ('bought', 51),
#  ('#slut', 51),
#  ('#naughty', 51),
#  ('#horny', 51),
#  ('meeting', 51),
#  ('bit', 51),
#  ('#fridayfeeling', 51),
#  ('#truth', 51),
#  ('mountains.', 51),
#  ("#father's", 51),
#  ('car', 51),
#  ('#gym', 51),
#  ('#coffee', 51),
#  ('#thankyou', 51),
#  ('welcome', 50),
#  ('gay', 50),
#  ('friday!', 50),
#  ('s', 50),
#  ('suppo', 50),
#  ('#shy', 50),
#  ('#nbafinals', 50),
#  ('sun', 50),
#  ('peace', 50),
#  ('sweet', 50),
#  ('source', 50),
#  ('gotta', 50),
#  ('vast', 50),
#  ('white', 50),
#  ('learn', 50),
#  ('late', 50),
#  ('cute', 50),
#  ('forget', 50),
#  ('#blur', 50),
#  ('later', 50),
#  ('funny', 50),
#  ('w', 49),
#  ('#style', 49),
#  ('name', 49),
#  ('point', 49),
#  ('truly', 49),
#  ('listen', 49),
#  ('safe', 49),
#  ('tomorrow!', 49),
#  ('#kinky', 49),
#  ('during', 49),
#  ('missing', 49),
#  ('easy', 49),
#  ('rooster', 49),
#  ('expanse', 49),
#  ('top', 49),
#  ('mass', 49),
#  ("couldn't", 49),
#  ('share', 49),
#  ('body', 49),
#  ('gave', 48),
#  ('#world', 48),
#  ('#people', 48),
#  ('#boy', 48),
#  ('state', 48),
#  ('takes', 48),
#  ('kill', 48),
#  ('#blue', 48),
#  ('rather', 48),
#  ('save', 48),
#  ('daily', 48),
#  ('wednesday', 48),
#  ('photo', 48),
#  ('dance', 47),
#  ('control', 47),
#  ('maybe', 47),
#  ('reading', 47),
#  ('#nasty', 47),
#  ('#xxx', 47),
#  ('this.', 47),
#  ('park', 47),
#  ('thinking', 47),
#  ("y'all", 47),
#  ('20', 47),
#  ('tv', 47),
#  ('walk', 47),
#  ('#vacation', 47),
#  ('using', 47),
#  ('business', 47),
#  ('arrived', 47),
#  ('wants', 47),
#  ('final', 47),
#  ('along', 47),
#  ('hello', 47),
#  ('lunch', 47),
#  ('child', 47),
#  ('crazy', 47),
#  ('#lol', 47),
#  ('celebrate', 46),
#  ('now!', 46),
#  ('latest', 46),
#  ('bless', 46),
#  ('lots', 46),
#  ('#followÃ¢Â\x80Â¦', 46),
#  ('called', 46),
#  ('families', 45),
#  ('ways', 45),
#  ('followers', 45),
#  ('vs', 45),
#  ('death', 45),
#  ('#wet', 45),
#  ('behind', 45),
#  ('#tired', 45),
#  ('everyday', 45),
#  ('chase:', 45),
#  ('break', 45),
#  ('evening', 45),
#  ('glad', 45),
#  ('days.', 45),
#  ('rip', 44),
#  ('#ripchristina', 44),
#  ('#alone', 44),
#  ('blessed', 44),
#  ('voice', 44),
#  ('#sunny', 44),
#  ('positive', 44),
#  ('leaving', 44),
#  ('mood', 44),
#  ('ask', 44),
#  ('dear', 44),
#  ('#dream', 44),
#  ('giving', 44),
#  ('Ã°Â\x9fÂ\x98Â\x8e', 43),
#  ('stuff', 43),
#  ('son', 43),
#  ('#usa', 43),
#  ('lose', 43),
#  ('na:', 43),
#  ('ass', 43),
#  ('#instamood', 43),
#  ('damn', 43),
#  ('everyone!', 43),
#  ('Ã°Â\x9fÂ\x98Â\x83', 43),
#  ('ago', 43),
#  ('#nice', 43),
#  ('#oitnb', 43),
#  ('phone', 43),
#  ('local', 43),
#  ('saying', 43),
#  ('here!', 43),
#  ('today,', 43),
#  ("who's", 42),
#  ('social', 42),
#  ('happening', 42),
#  ('8', 42),
#  ('spend', 42),
#  ('instead', 42),
#  ('move', 42),
#  ('minutes', 42),
#  ('#couple', 42),
#  ('boys', 42),
#  ('#best', 42),
#  ('#pretty', 42),
#  ('wonder', 42),
#  ('previous', 41),
#  ('forever', 41),
#  ('due', 41),
#  ('word', 41),
#  ("she's", 41),
#  ('worst', 41),
#  ('again.', 41),
#  ('staed', 41),
#  ('#laugh', 41),
#  ('fantastic', 41),
#  ('tonight.', 41),
#  ('told', 41),
#  ('anymore', 41),
#  ('line', 40),
#  ('#inspirational', 40),
#  ('#healing!!', 40),
#  ('shows', 40),
#  ('event', 40),
#  ('probably', 40),
#  ('#snapshot', 40),
#  ('hot', 40),
#  ('#e32016', 40),
#  ('#friendship', 40),
#  (':-)', 40),
#  ("we've", 40),
#  ("here's", 40),
#  ('#melancholy', 40),
#  ('hell', 40),
#  ('club', 40),
#  ('....', 40),
#  ('anniversary', 40),
#  ('literally', 40),
#  ('thursday', 40),
#  ('life!', 40),
#  ('#inshot', 40),
#  ('parents', 40),
#  ('Ã°Â\x9fÂ\x98Â\xad', 39),
#  ('means', 39),
#  ('#like4like', 39),
#  ('afternoon', 39),
#  ('lucky', 39),
#  ('reason', 39),
#  ('sexy', 39),
#  ('green', 39),
#  ('#instalike', 39),
#  ('#healing!', 39),
#  ('#nofilter', 39),
#  ("we'll", 39),
#  ('absolutely', 39),
#  ('group', 39),
#  ('#nyc', 39),
#  ('met', 39),
#  ('tuesday', 39),
#  ('leakage', 39),
#  ('weekend!', 39),
#  ('yesterday', 39),
#  ('picture', 39),
#  ('took', 39),
#  ('small', 39),
#  ('Ã¢Â\x80Â¢', 39),
#  ('though', 39),
#  ('ahead', 39),
#  ('ok', 39),
#  ('july', 39),
#  ('three', 39),
#  ('huge', 38),
#  ('fan', 38),
#  ('#ff', 38),
#  ('vote', 38),
#  ('human', 38),
#  ('#dads', 38),
#  ('loves', 38),
#  ('#vegan', 38),
#  ('#instadaily', 38),
#  ('listening', 38),
#  ('#dogs', 38),
#  ('#dj', 38),
#  ('red', 38),
#  ('#makeup', 38),
#  ('week.', 38),
#  ('woman', 38),
#  ('shot', 38),
#  ('#celebrate', 38),
#  ('different', 38),
#  ...]

# %% [markdown]
# ### As you can see, common words like "the" appear very often in both positive and negative twwts. Instead of finding the most common words in positive or negative tweets, what you really want are the words found in positive reviews more often than in negative tweets, and vice versa. To accomplish this, you'll need to calculate the ratios of word usage between positive and negative tweets.

# %%
pos_neg_ratios = Counter()

for term,cnt in list(total_counts.most_common()):
    if cnt > 100:
        pos_neg_ratios[term] = positive_counts[term] / (negative_counts[term]+1.0)

# %%
print(pos_neg_ratios['the'])
# Out:
# 0.08821621621621621

# %%
print(pos_neg_ratios["love"])
# Out:
# 0.011818181818181818

# %%
print(pos_neg_ratios["hate"])
# Out:
# 0.24193548387096775

# %%
pos_neg_ratios.most_common()[:30]
# Out:
# [('#trump', 3.1315789473684212),
#  ('white', 2.0392156862745097),
#  ('listen', 1.14),
#  ('against', 0.9841269841269841),
#  ('black', 0.9186046511627907),
#  ('women', 0.8064516129032258),
#  ('trump', 0.6153846153846154),
#  ('might', 0.5273972602739726),
#  ('sex', 0.37777777777777777),
#  ('says', 0.33707865168539325),
#  ('video', 0.31868131868131866),
#  ("isn't", 0.2962962962962963),
#  ('why', 0.27439024390243905),
#  ('because', 0.25572519083969464),
#  ('.@user', 0.2523364485981308),
#  ('hate', 0.24193548387096775),
#  ('should', 0.22388059701492538),
#  ('Ã¢Â\x80Â¦', 0.21447721179624665),
#  ('are', 0.21087978509066488),
#  ('thought', 0.21052631578947367),
#  ('same', 0.21),
#  ('&amp;', 0.20412844036697247),
#  ('girls', 0.19811320754716982),
#  (',', 0.19727891156462585),
#  ('his', 0.19617224880382775),
#  ('?', 0.19463087248322147),
#  ('feel', 0.19218241042345277),
#  ('must', 0.19148936170212766),
#  ('own', 0.18461538461538463),
#  ('stop', 0.18435754189944134)]

# %%
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('#inspiration', 0.0),
#  ('#hot', 0.0),
#  ('#healing', 0.0),
#  ('saturday', 0.0),
#  ('#cool', 0.0),
#  ('fun', 0.0),
#  ('#beach', 0.0),
#  ('simulation:', 0.0),
#  ('happiness', 0.0),
#  ('#wedding', 0.0),
#  ('adapt', 0.0),
#  ('simulator:', 0.0),
#  ('environment.', 0.0),
#  ('#travel', 0.0),
#  ('&lt;3', 0.0),
#  ('Ã°Â\x9fÂ\x98Â\x8d', 0.0),
#  (':(', 0.0),
#  ('tear', 0.0),
#  ('day.', 0.0),
#  ('smile', 0.0),
#  ('#tbt', 0.0),
#  ('#euro2016', 0.0),
#  ('#a', 0.0),
#  ('#dog', 0.0),
#  ('#fashion', 0.0),
#  ('Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8f', 0.0),
#  ('#girl', 0.0),
#  ('#work', 0.0),
#  ('#photooftheday', 0.0),
#  ('bong', 0.0)]

# %%
for word,ratio in pos_neg_ratios.most_common():
    pos_neg_ratios[word] = np.log(ratio)
# Out:
# /home/heimdall/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
vocab = set(total_counts.keys())
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 67168

# %%
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'meee!!!!': 1,
#  '#bangsean': 2,
#  'camden!...': 3,
#  '#cjreform?': 4,
#  'gen.': 5,
#  'clothes,': 6,
#  '#singalong': 7,
#  'post]': 8,
#  '#josie': 9,
#  '#justkeepswimming': 10,
#  'russia': 11,
#  'rabid': 12,
#  '#goodtv': 13,
#  'equipment.': 14,
#  '#blackmagic': 15,
#  'buraa': 16,
#  'conÃ¢Â\x80Â¦': 17,
#  '57': 18,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x91Â«': 19,
#  '#shame': 20,
#  'kickstaer.': 21,
#  '#socloseyetsofar': 22,
#  'legacy!!!': 23,
#  'design.': 24,
#  'digging': 25,
#  'Ã°Â\x9fÂ\x98Â¢Ã°Â\x9fÂ\x98Â¢Ã°Â\x9fÂ\x8dÂ´Ã¢Â\x9dÂ\x8c': 26,
#  '#lostinthemuseum2016': 27,
#  'ill,': 28,
#  '#rother': 29,
#  'know,': 30,
#  'Ã¢Â\x9eÂª': 31,
#  'Ã¢Â\x98ÂºÃ°Â\x9fÂ\x99Â\x86': 32,
#  '#fitnesscentre': 33,
#  '#zucchini': 34,
#  '#edenandjaysbestday': 35,
#  '#sounda': 36,
#  'challenge!': 37,
#  '#bakery': 38,
#  'Ã°Â\x9fÂ\x8dÂ\x81Ã¢Â\x9cÂ\x88Ã¯Â¸Â\x8fgreat': 39,
#  '#paylife': 40,
#  '#rosie': 41,
#  '#staystrong': 42,
#  'stiff': 43,
#  'peyton': 44,
#  'offer.': 45,
#  '#violence!': 46,
#  '-10/06/16': 47,
#  'dawned': 48,
#  'abby': 49,
#  'dying': 50,
#  '#timbuon': 51,
#  'Ã¢Â\x80Â\x9cgood': 52,
#  '73.67%...': 53,
#  '#chillin': 54,
#  'realÃ¢Â\x80Â¦': 55,
#  'jockey': 56,
#  'before-bed': 57,
#  '&amp;dream': 58,
#  'shyt.': 59,
#  '#celebspot': 60,
#  ',Ã¢Â\x80Â¦': 61,
#  'google': 62,
#  'legendary': 63,
#  'Ã°Â\x9fÂ\x8dÂ\x94Ã°Â\x9fÂ\x98Â\x81': 64,
#  'ibiza.': 65,
#  '#psyched.': 66,
#  'day!tuesdays': 67,
#  'herÃ¢Â\x80Â¦': 68,
#  'indie': 69,
#  '#poppetmaster': 70,
#  '#bigeventforme': 71,
#  '#resolution': 72,
#  '#kohlisoonÃ\x82Â\xa0': 73,
#  'genocide?': 74,
#  'friendÃ°Â\x9fÂ\x92Â\x85Ã°Â\x9fÂ\x8fÂ¼': 75,
#  'faiths,Ã¢Â\x80Â¦': 76,
#  'friggin': 77,
#  '#colorsay': 78,
#  'oak': 79,
#  'brisk_and_ham-on_and_on_(slipmatt_remix)-(ng010)-web-1998-ukhx_int': 80,
#  '1:80': 81,
#  '1.4440': 82,
#  '32': 83,
#  'florida': 84,
#  '#lovetotravelalloveheworldÃ¢Â\x80Â¦': 85,
#  'peeling': 86,
#  'heat."': 87,
#  'irelands': 88,
#  'negative': 89,
#  '#greatpeople': 90,
#  'dj_ham-new_style__your_love-(ng018)-web-1998-ukhx_int': 91,
#  'bridget': 92,
#  'Ã°Â\x9fÂ\x98Â³Ã°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x8cÂ¸': 93,
#  '#themaineaudition': 94,
#  'Ã°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x99Â\x8f': 95,
#  '#fearlessÃ¢Â\x80Â¦': 96,
#  '#ptxworldtour': 97,
#  'nose': 98,
#  'letterkenny': 99,
#  '#smilepowerday!': 100,
#  "wife's": 101,
#  'listing': 102,
#  '#unchaed': 103,
#  "pep's": 104,
#  'holder': 105,
#  '#bernielostme': 106,
#  'sunrise': 107,
#  '#amwriting': 108,
#  '#stylistic#': 109,
#  '6': 110,
#  '#songwriter.': 111,
#  'chuckled': 112,
#  '#navyyard': 113,
#  'heskin': 114,
#  'rebeccas': 115,
#  "dogmeetsfamily's": 116,
#  "india's": 117,
#  'fw': 118,
#  'manzini': 119,
#  'pumped!': 120,
#  'banking': 121,
#  'fascists': 122,
#  'royale': 123,
#  '#bestabiamo': 124,
#  'sack': 125,
#  'not?"': 126,
#  '13hrs': 127,
#  'Ã°Â\x9fÂ\x92Â\x95Ã°Â\x9fÂ\x92Â\x9e': 128,
#  '#truthseekers': 129,
#  '#sundayfun': 130,
#  '#whererefreshingbegins': 131,
#  '#thestarspangledbanner': 132,
#  '#gbe': 133,
#  '#hamr': 134,
#  '"mini': 135,
#  'place???': 136,
#  'assist': 137,
#  '30': 138,
#  'campeon': 139,
#  '#5years': 140,
#  'Ã°Â\x9fÂ\x91Â\x8dÃ°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x98Â\x8e': 141,
#  'bating': 142,
#  "#dad's/": 143,
#  "'star": 144,
#  'ideal.': 145,
#  'Ã°Â\x9fÂ\x8eÂ¤Ã°Â\x9fÂ\x8eÂµÃ°Â\x9fÂ\x8eÂ¶Ã°Â\x9fÂ\x8eÂ¸': 146,
#  '#22': 147,
#  'meÃ¢Â\x9dÂ¤Ã¯Â¸Â\x8f': 148,
#  '#nickjonas': 149,
#  'minimum': 150,
#  'Ã°Â\x9fÂ\x8dÂ\x95': 151,
#  '-yeehaaaw-': 152,
#  'some!!!': 153,
#  '#ecto1': 154,
#  '#fact': 155,
#  '#lbgt': 156,
#  '#deceitful': 157,
#  '#mentors': 158,
#  'economy.': 159,
#  'caption!': 160,
#  '#grandmothers': 161,
#  'stain': 162,
#  'a?': 163,
#  '(did': 164,
#  '#love#instadaily': 165,
#  'asylum.': 166,
#  'Ã°Â\x9fÂ\x98Â\x99Ã°Â\x9fÂ\x91Â\x8c': 167,
#  '#salary': 168,
#  'nicole.': 169,
#  'loversÃ¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x91Â\x91Ã°Â\x9fÂ\x91Â¸Ã°Â\x9fÂ\x8fÂ»': 170,
#  '#flowerofjoy': 171,
#  '#skinny': 172,
#  'Ã°Â\x9fÂ\x98Â\x83Ã¢Â\x9cÂ\x88Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x8eÂ\x89Ã¢Â\x98Â\x80Ã¯Â¸Â\x8f': 173,
#  'teaser!': 174,
#  '#interview': 175,
#  'faster': 176,
#  'hysterically?': 177,
#  'at?"': 178,
#  'lo': 179,
#  'islam': 180,
#  'Ã°Â\x9fÂ\x98Â\x92Ã°Â\x9fÂ\x98Â\x92Ã°Â\x9fÂ\x98Â\x92': 181,
#  'somewhere,': 182,
#  'world.': 183,
#  '#vaÃ¢Â\x80Â¦': 184,
#  'puffs': 185,
#  '#byebye': 186,
#  'complete!!': 187,
#  '#ilovepaint': 188,
#  'clientele': 189,
#  '#fatherson#': 190,
#  'turns': 191,
#  'concerned': 192,
#  'paner+i': 193,
#  'crow': 194,
#  '#goskate': 195,
#  'stone!!!': 196,
#  '#snorkeling': 197,
#  'someÃ°Â\x9fÂ\x92Â\x8b': 198,
#  '#ishir': 199,
#  '#baahubali': 200,
#  '#delhi': 201,
#  'generations': 202,
#  '#britishweathersucks': 203,
#  '#inaspanof': 204,
#  'beg': 205,
#  '#ss16': 206,
#  'extensions': 207,
#  'stint': 208,
#  'california': 209,
#  'us!': 210,
#  '#photooftoday': 211,
#  'discol': 212,
#  'student!': 213,
#  '#goodsunday': 214,
#  'whitey': 215,
#  '#overdose': 216,
#  'fan?': 217,
#  '#youthday': 218,
#  'unbelievable': 219,
#  '#ramodmalaka': 220,
#  'over-rode': 221,
#  '#rec405': 222,
#  'Ã°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x92Â\x8b': 223,
#  'releases': 224,
#  '#vbs2016': 225,
#  'spot': 226,
#  'but,': 227,
#  '#smilers': 228,
#  '#hedgehog': 229,
#  'smiling,': 230,
#  'agent': 231,
#  'guns?': 232,
#  'selah': 233,
#  '6p': 234,
#  'oprah,': 235,
#  'headlines!!!!': 236,
#  'tickets:': 237,
#  '#conveibleÃ¢Â\x80Â¦': 238,
#  'mints': 239,
#  'kana??': 240,
#  '#flip': 241,
#  '#psa': 242,
#  '#bars': 243,
#  'puzzle': 244,
#  'teach': 245,
#  'xoxo': 246,
#  'graffiti': 247,
#  'trouble.': 248,
#  'ensure': 249,
#  'while': 250,
#  '#tunbridgewells': 251,
#  '#loveÃ°Â\x9fÂ\x91Â¼': 252,
#  '#wwefi': 253,
#  'jaggi': 254,
#  'app:': 255,
#  '#kitten#keith#8weeks#waitinggame': 256,
#  '#show...': 257,
#  'Ã°Â\x9fÂ\x92Â\x8bÃ°Â\x9fÂ\x98Â\x8bÃ°Â\x9fÂ\x98Â\x85': 258,
#  '46': 259,
#  'cut,': 260,
#  'much,much': 261,
#  'delays': 262,
#  'drop,': 263,
#  'retimed': 264,
#  '#durdledoor': 265,
#  'take?': 266,
#  'top!': 267,
#  '#tech': 268,
#  'dog...is': 269,
#  'trafficking': 270,
#  '#ecofriendly': 271,
#  '#bogum616day': 272,
#  '#greattracks': 273,
#  '#businessgoals': 274,
#  'unfiltered': 275,
#  'fears.': 276,
#  '#universe': 277,
#  '#behdayÃ¢Â\x80Â¦': 278,
#  '2:30am': 279,
#  'imyyyyÃ°Â\x9fÂ\x98Â\x98': 280,
#  '#nationalvegetableday': 281,
#  '#beseen': 282,
#  'ootnÃ°Â\x9fÂ\x92Â\x81Ã°Â\x9fÂ\x8fÂ»#nightout': 283,
#  'argh!': 284,
#  'proved': 285,
#  '#stream!': 286,
#  'sylvia': 287,
#  'werdz?': 288,
#  '#jews.': 289,
#  'Ã³Â¾Â\x81Â\x98Ã³Â¾Â\x81Â\x98Ã³Â¾Â\x81Â\x98': 290,
#  '#muskoka': 291,
#  '#celticpoetry': 292,
#  'suicides.': 293,
#  'form': 294,
#  '#dancemoms3': 295,
#  'Ã°Â\x9fÂ\x87Â¨Ã°Â\x9fÂ\x87Â¦Ã°Â\x9fÂ\x87Â¨Ã°Â\x9fÂ\x87Â¦Ã°Â\x9fÂ\x87Â¨Ã°Â\x9fÂ\x87Â¦': 296,
#  'wise...Ã°Â\x9fÂ\x98Â\x8e': 297,
#  '#pug': 298,
#  'store.': 299,
#  'hindus': 300,
#  'victims!': 301,
#  '#dahlia': 302,
#  '#fitnessfriday': 303,
#  'somalia': 304,
#  '#terrabitesfood': 305,
#  '#booze': 306,
#  'holy': 307,
#  '#effluent': 308,
#  'race...': 309,
#  '#tedatibm': 310,
#  'branch.': 311,
#  'bihdayswayÃ°Â\x9fÂ\x92Â\x99': 312,
#  '#do': 313,
#  '#scaredfohefuture': 314,
#  'Ã°Â\x9fÂ\x91Â°Ã°Â\x9fÂ\x91Â°Ã°Â\x9fÂ\x91Â°Ã°Â\x9fÂ\x91Â«Ã°Â\x9fÂ\x91Â«': 315,
#  "fiddler's": 316,
#  'deliveries': 317,
#  '#byecar': 318,
#  'played.': 319,
#  'trashing': 320,
#  '#makesomeonesmiletoday': 321,
#  'recession': 322,
#  'face"': 323,
#  'shops.': 324,
#  'riddance!': 325,
#  'reciprocated.': 326,
#  'admirer': 327,
#  'trump.': 328,
#  '#bump': 329,
#  '#cat': 330,
#  '#grayneedstogo': 331,
#  'indefensible.': 332,
#  'governor:': 333,
#  '#sesekali': 334,
#  'fohcoming': 335,
#  '#unbiosibs': 336,
#  'third': 337,
#  '#justice': 338,
#  '#westboro': 339,
#  'te': 340,
#  '("': 341,
#  '&lt;---my': 342,
#  'streetÃ¢Â\x80Â¦': 343,
#  'shane': 344,
#  'students.': 345,
#  '#bangerztour': 346,
#  '#weapons': 347,
#  'please!!!': 348,
#  'loathsome': 349,
#  'district': 350,
#  'Ã°Â\x9fÂ\x91Â\x8fÃ°Â\x9fÂ\x8fÂ¼Ã°Â\x9fÂ\x98Â\x82': 351,
#  'along.': 352,
#  'awwww...': 353,
#  '#produce101teachers': 354,
#  'tumor': 355,
#  '#cantkeepmymouthshut': 356,
#  'then,': 357,
#  'awarded': 358,
#  'nvr': 359,
#  '#wrath,': 360,
#  '#recording!': 361,
#  'Ã°Â\x9fÂ\x91Â\x86link': 362,
#  'happy..': 363,
#  'lawyer:': 364,
#  '#runnerslife': 365,
#  'speech.': 366,
#  'Ã°Â\x9fÂ¤Â\x93Ã°Â\x9fÂ\x92Â\x8b': 367,
#  'grumpy': 368,
#  'chidi': 369,
#  'lead...': 370,
#  'stranger': 371,
#  'Ã°Â\x9fÂ\x98Â\x8cÃ°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x98Â\x8a': 372,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fu': 373,
#  '#ledger,': 374,
#  'savoryandsweetfood': 375,
#  '#shamelessly': 376,
#  '#functionsÃ¢Â\x80Â¦': 377,
#  'healthcaÃ¢Â\x80Â¦': 378,
#  '#dignitas': 379,
#  '#actorlife': 380,
#  'buckley': 381,
#  'sure?': 382,
#  '#merica': 383,
#  '5pm': 384,
#  '#yikez': 385,
#  'compliments': 386,
#  'muslims!': 387,
#  'blm': 388,
#  'mfc,': 389,
#  '#beautyblogger': 390,
#  'asking.': 391,
#  '#hoppy': 392,
#  '#failure?': 393,
#  'liked^^': 394,
#  'tomorrow)': 395,
#  'kyrie,': 396,
#  'gt': 397,
#  'deeply!!!': 398,
#  'manning...': 399,
#  '#lifeatihg': 400,
#  'frighteningly': 401,
#  'think...we': 402,
#  'herself': 403,
#  'e3': 404,
#  'business': 405,
#  'ndigbo': 406,
#  '#streetmusica': 407,
#  'fire!': 408,
#  'bday!': 409,
#  'Ã°Â\x9fÂ\x98Â\x8dÃ°Â\x9fÂ\x98Â\x8dÃ°Â\x9fÂ\x98Â\x84Ã°Â\x9fÂ\x92Â\x9c': 410,
#  '#beardsofinstagramÃ¢Â\x80Â¦': 411,
#  '#harassment,': 412,
#  '#beoplay': 413,
#  'remodeling': 414,
#  '#poes': 415,
#  '#inloveÃ¢Â\x80Â¦': 416,
#  '#keepenjoy': 417,
#  'kitties.': 418,
#  '#stayblessed': 419,
#  '-some-': 420,
#  'bsÃ°Â\x9fÂ\x99Â\x84': 421,
#  '(mainly': 422,
#  '#momentos': 423,
#  '#lincsconnect': 424,
#  'nandita': 425,
#  'champagne': 426,
#  '#dudes': 427,
#  'guilbe': 428,
#  'pub!': 429,
#  'procreate!': 430,
#  '#january': 431,
#  'mugs': 432,
#  '#bihday': 433,
#  'silverado!': 434,
#  '#metalheadÃ¢Â\x80Â¦': 435,
#  '"nope"': 436,
#  'referring': 437,
#  'exploring': 438,
#  'equals....Ã\x82Â\xa0a': 439,
#  "'tail'": 440,
#  '#aupair#aupairlife': 441,
#  '#baycityrollers': 442,
#  'Ã¢Â\x98Â\x80Ã°Â\x9fÂ\x8cÂ\x9fÃ¢Â\x98Â\x80': 443,
#  'forecasts': 444,
#  'alyssa': 445,
#  'ignored....': 446,
#  'comics:': 447,
#  '#corporatecharitychampionoftheyear': 448,
#  'Ã¢Â\x99Â¥min': 449,
#  '#fatty.': 450,
#  '#british': 451,
#  'corny': 452,
#  'being.Ã¢Â\x80Â\x9d': 453,
#  'tenure': 454,
#  '#revisions': 455,
#  'tin': 456,
#  '#mondayblues': 457,
#  '#followers!': 458,
#  '#amarinder': 459,
#  'boys!': 460,
#  '#glasto': 461,
#  'chingola': 462,
#  'crown': 463,
#  'vai': 464,
#  'muad.': 465,
#  '#farm-dogs': 466,
#  '#damonsajnani': 467,
#  '#theedge': 468,
#  '#needbreakfastÃ¢Â\x80Â¦': 469,
#  'Ã°Â\x9fÂ\x92Â¡Ã°Â\x9fÂ\x91Â\x89Ã¢Â\x80Â¦': 470,
#  'chic': 471,
#  'Ã¢Â\x9cÂ¨Ã°Â\x9fÂ\x92Â\xad': 472,
#  '#onmyway': 473,
#  'energized.': 474,
#  'gmorn!Ã°Â\x9fÂ\x8cÂ\x9eÃ°Â\x9fÂ\x90Â¯Ã°Â\x9fÂ\x92Â\x9b': 475,
#  '#yehtut': 476,
#  "paladino's": 477,
#  'skrillex': 478,
#  '#manor': 479,
#  '#dribbble': 480,
#  'greedy': 481,
#  '#nextstep': 482,
#  '#conquercancer': 483,
#  'Ã°Â\x9fÂ\x91Â\x8c#airpo': 484,
#  '#namibianpoet': 485,
#  'late...too': 486,
#  '#haÃ¢Â\x80Â¦': 487,
#  '#grimmie': 488,
#  'misogyny': 489,
#  'mins': 490,
#  '(#mw2)': 491,
#  '#walkingÃ¢Â\x80Â¦': 492,
#  'clio': 493,
#  '350s': 494,
#  '#Ã£Â\x83Â¡Ã£Â\x83ÂªÃ£Â\x83Â¼Ã£Â\x83Â\x9dÃ£Â\x83Â\x94Ã£Â\x83Â³Ã£Â\x82Âº': 495,
#  'Ã°Â\x9fÂ\x8cÂ\x8eÃ°Â\x9fÂ\x8cÂ·': 496,
#  'soooooooooo': 497,
#  'paies': 498,
#  'midday': 499,
#  'dhin': 500,
#  '229': 501,
#  'bodega': 502,
#  '#confidence,': 503,
#  'tim': 504,
#  'nature!': 505,
#  '#discipline': 506,
#  'game!': 507,
#  'weeheeeee~': 508,
#  '#ski': 509,
#  'wrendavis': 510,
#  '#trumpdallas': 511,
#  'skype:': 512,
#  '#faithful': 513,
#  'sub,': 514,
#  "u're": 515,
#  'clap': 516,
#  'bunch.': 517,
#  'evenings.': 518,
#  '#unbiosibsÃ¢Â\x80Â¦': 519,
#  'erich': 520,
#  'long...': 521,
#  '18]': 522,
#  '#focusonthegood': 523,
#  '#joyas': 524,
#  '#actors': 525,
#  '#denim': 526,
#  '#dongiovanni': 527,
#  'parin': 528,
#  'more:': 529,
#  '#selfie': 530,
#  'tent.': 531,
#  'pressed.': 532,
#  'tue.': 533,
#  'maggie': 534,
#  '#dahvader': 535,
#  'does.': 536,
#  '2/2': 537,
#  '#libcrib': 538,
#  'eerie': 539,
#  '#deletetweets': 540,
#  'legends': 541,
#  'waiting...all': 542,
#  '#cutequotes': 543,
#  'off!!!!!': 544,
#  'Ã°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x8fÂ½Ã°Â\x9fÂ\x92Â\x95': 545,
#  'memoire': 546,
#  'lls': 547,
#  'flamengo': 548,
#  '#pllseason7': 549,
#  '#couple': 550,
#  '#careerrocks': 551,
#  'yoh': 552,
#  '#gettingready': 553,
#  '#silveÃ¢Â\x80Â¦': 554,
#  '#19days': 555,
#  '#nowplaying': 556,
#  '#highpeaks': 557,
#  'value!': 558,
#  '#digitalrevolution': 559,
#  'ngos': 560,
#  '#paradox': 561,
#  '#youcandothis': 562,
#  '#shihtzu': 563,
#  'project.': 564,
#  'awesome-day?': 565,
#  '#dailypoll': 566,
#  'Ã°Â\x9fÂ\x8cÂ\x90': 567,
#  'freed': 568,
#  '#nintendoe3': 569,
#  '#frump!': 570,
#  'mk': 571,
#  '#pbcrave': 572,
#  '#torbayairshow': 573,
#  'joyful.': 574,
#  '21.': 575,
#  '#tiredashell': 576,
#  '#systemicracism': 577,
#  '#fashionshows#bridalweekend': 578,
#  'sold': 579,
#  'netflix': 580,
#  'he...': 581,
#  'journlst': 582,
#  '#hens': 583,
#  'devalue': 584,
#  '#cosplay': 585,
#  'sphere!': 586,
#  'destination,': 587,
#  'hybrid': 588,
#  'dacks!': 589,
#  'thirst': 590,
#  'rising!': 591,
#  '#cielphantomhive': 592,
#  '55th': 593,
#  'hillary,': 594,
#  '#bigpharma': 595,
#  'dad...Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8f': 596,
#  '#readÃ¢Â\x80Â¦': 597,
#  '#pennsylvania': 598,
#  'rearing': 599,
#  "noah's": 600,
#  'aed': 601,
#  '#clintonforprison': 602,
#  'tackle': 603,
#  'Ã°Â\x9fÂ\x90Â¶Ã°Â\x9fÂ¤Â\x98Ã°Â\x9fÂ\x8fÂ¼': 604,
#  'babe"': 605,
#  '#shemad': 606,
#  '9919': 607,
#  '#july': 608,
#  '#rosa': 609,
#  '#monies': 610,
#  '#orangeisthenewblack': 611,
#  'patronizing': 612,
#  '#glorious': 613,
#  '#maari': 614,
#  '#now,': 615,
#  '-.-': 616,
#  '#Ã§Â\x8cÂ«': 617,
#  '#harleydavidson': 618,
#  'rough': 619,
#  '#darling': 620,
#  '#ramshackle': 621,
#  '#mummybloggers': 622,
#  'sicker': 623,
#  'Ã°Â\x9fÂ\x98Â\x8eÃ°Â\x9fÂ\x98Â\x8eÃ°Â\x9fÂ\x98Â\x8e': 624,
#  'biryhday': 625,
#  'instinct,': 626,
#  'mullahs': 627,
#  '#sunny': 628,
#  'huh...': 629,
#  'end..........': 630,
#  '#healthyfood': 631,
#  '#feminist,': 632,
#  '#ontheredcarpet': 633,
#  '#regrann': 634,
#  'y': 635,
#  'daves': 636,
#  '#wyonnaearp': 637,
#  'while.': 638,
#  'barbican': 639,
#  'gran': 640,
#  '#manilow': 641,
#  '#bringiton': 642,
#  'communism.': 643,
#  'obligation.': 644,
#  '#steve': 645,
#  '#makelife': 646,
#  'whether': 647,
#  '#fragrantjewels': 648,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x8eÂ¯': 649,
#  '#keepgoing': 650,
#  '#flagfriday': 651,
#  ':(': 652,
#  'ave.': 653,
#  'land.': 654,
#  '#clubtuas': 655,
#  'revised': 656,
#  'Ã¢Â\x9aÂ¡who': 657,
#  '#genting': 658,
#  '#lifesaver': 659,
#  'whoop,': 660,
#  'Ã°Â\x9fÂ\x8cÂ¸Ã°Â\x9fÂ\x8eÂ¤xx': 661,
#  'gimme:': 662,
#  'multiple': 663,
#  'sent': 664,
#  'ruins': 665,
#  'approved,': 666,
#  '#wbencconf': 667,
#  '#cherry': 668,
#  'placed!': 669,
#  '#satinderkariha': 670,
#  'embarrassing': 671,
#  'life....': 672,
#  'ww,': 673,
#  '#livinÃ¢Â\x80Â¦': 674,
#  "mark's": 675,
#  '#timwise': 676,
#  '#mfact': 677,
#  'cultures': 678,
#  'Ã°Â\x9fÂ\x98Â¶': 679,
#  '#presentmood': 680,
#  '#paramore': 681,
#  '#anotherwomanwedding': 682,
#  'itz': 683,
#  '#prose': 684,
#  'Ã°Â\x9fÂ\x98Â\x80Ã°Â\x9fÂ\x98Â\x80Ã°Â\x9fÂ\x98Â\x80Ã°Â\x9fÂ\x98Â\x80': 685,
#  '(hd': 686,
#  'mockery': 687,
#  '#yummy': 688,
#  '"your': 689,
#  'jo': 690,
#  'bigot?': 691,
#  '(ken)': 692,
#  'creator': 693,
#  'connection.': 694,
#  '#gmspastorsretreat2016': 695,
#  'rising': 696,
#  '#hhwear': 697,
#  'successful,': 698,
#  'monthly': 699,
#  '#dancers': 700,
#  'points': 701,
#  '#intolerance': 702,
#  'sense': 703,
#  '#saynotodrugs': 704,
#  'siste': 705,
#  'hyena': 706,
#  'Ã°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x93Â¦Ã°Â\x9fÂ\x9aÂ\x9a': 707,
#  'Ã°Â\x9fÂ\x92Â\x9bÃ¢Â\x98Â\x80Ã¯Â¸Â\x8f': 708,
#  '#bleedpurple': 709,
#  '#libeypr': 710,
#  'aud/nzd': 711,
#  '#firsttime': 712,
#  '#singsnap': 713,
#  '#allday': 714,
#  'weather': 715,
#  'Ã¯Â¼Â\x83cute': 716,
#  'alapoet:': 717,
#  'c2c': 718,
#  '#indiegame': 719,
#  '&amp;thankful': 720,
#  'squiin': 721,
#  'Ã°Â\x9fÂ\x8cÂ\x9eÃ°Â\x9fÂ\x8eÂªÃ°Â\x9fÂ\x8cÂ³Ã°Â\x9fÂ\x8cÂ¼Ã°Â\x9fÂ\x8dÂ\x96Ã°Â\x9fÂ\x8dÂ³Ã°Â\x9fÂ\x8cÂ¶Ã°Â\x9fÂ\x8cÂ½Ã°Â\x9fÂ\x8dÂ\x99': 722,
#  '#newyorkÃ¢Â\x80Â¦': 723,
#  'theater': 724,
#  'werewolf': 725,
#  'Ã°Â\x9fÂ\x98Â\x81Ã°Â\x9fÂ\x98Â\x9cÃ°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x98Â\x85#me#selfie#today': 726,
#  'precious..': 727,
#  'inhabitant.': 728,
#  'play': 729,
#  'colors!': 730,
#  '#thehappinets': 731,
#  'hello.': 732,
#  '#betrayal': 733,
#  '#3bookstogo': 734,
#  'natin': 735,
#  'leftover': 736,
#  'thursday!Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ¾Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ¾Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ¾': 737,
#  'critiquing': 738,
#  'prettiest': 739,
#  '#unpresidented': 740,
#  'thrilling.': 741,
#  'bcoz': 742,
#  '#rivieramaya': 743,
#  'oppounities:': 744,
#  'common,': 745,
#  '#dadnme': 746,
#  'baby!!': 747,
#  'negative...': 748,
#  'ish': 749,
#  '#fullnessÃ¢Â\x80Â¦': 750,
#  '#summeimeflowers': 751,
#  'heas"': 752,
#  '*this*': 753,
#  '#25': 754,
#  'Ã¢Â\x99Â¥rap': 755,
#  '#bihdaynightout': 756,
#  'coopting': 757,
#  'producers': 758,
#  'thanking': 759,
#  '#stateofwomen': 760,
#  'preview:': 761,
#  'blah': 762,
#  'pvp': 763,
#  '#lovecamping': 764,
#  '6%': 765,
#  '#airconditioner': 766,
#  "happyfather'sdayÃ°Â\x9fÂ\x91Â¨Ã°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x8cÂ¹": 767,
#  'wish...': 768,
#  '#msc': 769,
#  'mayuko!!!': 770,
#  'mediocre': 771,
#  'enteain': 772,
#  'won!!!!!': 773,
#  'fallon': 774,
#  '#grandfinal': 775,
#  'veterans.': 776,
#  "up'": 777,
#  '#policetraining': 778,
#  'tomato': 779,
#  'waterloo.': 780,
#  '"elizabeth': 781,
#  '#paners': 782,
#  'dancing!': 783,
#  'sureÃ¢Â\x80Â¦': 784,
#  'lock': 785,
#  '#travelpics': 786,
#  'anniversary!!Ã°Â\x9fÂ\x92Â\x90Ã°Â\x9fÂ\x8eÂ\x82Ã°Â\x9fÂ\x98Â\x98Ã°Â\x9fÂ\x8eÂ\x81Ã°Â\x9fÂ\x8eÂ\x81': 787,
#  'cup,': 788,
#  'swim!!': 789,
#  'nobodies': 790,
#  '#jokes,': 791,
#  'ashton': 792,
#  '#runnerdad': 793,
#  '#offend': 794,
#  'wednesday...': 795,
#  '27th...our': 796,
#  'controlled': 797,
#  'jessiestyman': 798,
#  'adams': 799,
#  '(dramatic,': 800,
#  'gloucestershire': 801,
#  '#refleÃ¢Â\x80Â¦': 802,
#  'first!)': 803,
#  '#sjws': 804,
#  '#goodtimeswithgoÃ¢Â\x80Â¦': 805,
#  'primary.@user': 806,
#  "shitheads'": 807,
#  '#erenromasadiyor': 808,
#  '#farrahangphotography': 809,
#  'fes.': 810,
#  'Ã°Â\x9fÂ\x91Â\x89Ã°Â\x9fÂ\x8fÂ»#pretending#to#be': 811,
#  '#farewell': 812,
#  'pills': 813,
#  'really!': 814,
#  '#instaviÃ\x83Â±a': 815,
#  'germany,': 816,
#  '#hamiltonmusical': 817,
#  'happened.': 818,
#  '#dead': 819,
#  'refined.#i_am': 820,
#  '#lollipop': 821,
#  'does,': 822,
#  "'devastating'": 823,
#  "he'll": 824,
#  'appear!!': 825,
#  '#marvelstheavengers': 826,
#  'chambers': 827,
#  '#Ã¬Â\x83Â\x9dÃ¬Â\x9dÂ¼Ã£Â\x85Â\x8aÃ£Â\x85Â\x8e': 828,
#  '#whiteamerica': 829,
#  'today...': 830,
#  'internationals': 831,
#  '!Ã°Â\x9fÂ\x92Â¤Ã°Â\x9fÂ\x92Â¤Ã°Â\x9fÂ\x97Â\x9dÃ°Â\x9fÂ\x97Â\x9dÃ°Â\x9fÂ\x8fÂ\xa0Ã°Â\x9fÂ\x8fÂ¡Ã°Â\x9fÂ\x8fÂ¡Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8f': 832,
#  '#populism': 833,
#  'begging...': 834,
#  '#newstyles': 835,
#  'shawnee': 836,
#  '#olives': 837,
#  'addresses': 838,
#  'prevented': 839,
#  'Ã°Â\x9fÂ\x98Â\x8bÃ°Â\x9fÂ\x92Â\x95Ã°Â\x9fÂ\x92Â\x95Ã°Â\x9fÂ\x92Â\x95': 840,
#  '#enoughisenough': 841,
#  '#castingcall': 842,
#  'yoakam': 843,
#  'lol!!!': 844,
#  'promotions?': 845,
#  'almost': 846,
#  'professionals': 847,
#  '#hfd': 848,
#  'all,': 849,
#  '"Ã¢Â\x80Â¦': 850,
#  '#unreformable': 851,
#  '#tabby': 852,
#  '#thanksgodÃ°Â\x9fÂ\x92Â\x99': 853,
#  'racism.': 854,
#  'youuu!!!!': 855,
#  'sucked': 856,
#  'zone,': 857,
#  '#employment': 858,
#  '#alaba': 859,
#  'determined': 860,
#  '#barney': 861,
#  '#nature##sea': 862,
#  '#bettehan': 863,
#  'oxygen': 864,
#  '#giftideas': 865,
#  'him..': 866,
#  '#mikado': 867,
#  'rigged/pathetic': 868,
#  'pfft.': 869,
#  'Ã¢Â\x98ÂºÃ¯Â¸Â\x8fÃ°Â\x9fÂ\x93Â\x9a': 870,
#  '#inawe': 871,
#  '#thebachelorette': 872,
#  'keshi,': 873,
#  '#litfest': 874,
#  'newsÃ°Â\x9fÂ\x98Â\x84Ã°Â\x9fÂ\x98Â\x84': 875,
#  '#ugly': 876,
#  'absÃ°Â\x9fÂ\x94Â¥': 877,
#  'punjab.': 878,
#  '#donteventryit': 879,
#  '13.8': 880,
#  'tomoro': 881,
#  '#trade': 882,
#  '#shape': 883,
#  'Ã\x82Â\xa0uniform': 884,
#  '#shanklin': 885,
#  'interesting......': 886,
#  'russell.beckwith': 887,
#  'midle': 888,
#  'respect': 889,
#  'needing': 890,
#  '#nbafinals2016': 891,
#  '#tos': 892,
#  'faves': 893,
#  '#ancestral': 894,
#  '#idc': 895,
#  'Ã¢Â\x98ÂºÃ¯Â¸Â\x8fÃ°Â\x9fÂ\x98Â\x8d.': 896,
#  'berke': 897,
#  '(Ã\x82Â¯`Ã¢Â\x99Â¥Ã\x82Â´Ã\x82Â¯)Ã¢Â\x95Â\x90&gt;': 898,
#  '#besuccessful': 899,
#  'be': 900,
#  'embodiment': 901,
#  'be4': 902,
#  '$3.5': 903,
#  '#buildings': 904,
#  '#cameraÃ¢Â\x80Â¦': 905,
#  'well;': 906,
#  'shit,': 907,
#  'pnc': 908,
#  '#djvarra': 909,
#  'rope': 910,
#  'fulfilling': 911,
#  'cancellations': 912,
#  'datas.': 913,
#  '#ofcourse': 914,
#  'conniving,': 915,
#  'Ã¢Â\x9cÂ\x8d': 916,
#  ';(': 917,
#  '#fantasticlies': 918,
#  'magnum': 919,
#  'google-': 920,
#  "imm'ts": 921,
#  '#getwhatyouwant': 922,
#  '#seals': 923,
#  'holiday,': 924,
#  '#flowÃ°Â\x9fÂ\x8dÂ·Ã°Â\x9fÂ\x92Â\x93#friends': 925,
#  'kennel': 926,
#  'herÃ°Â\x9fÂ\x98Â\x82#mylittlepony': 927,
#  '#tried': 928,
#  '#themoodcards': 929,
#  'perspective': 930,
#  '#duduk': 931,
#  '#whitepaper': 932,
#  '#boiledpeanuts': 933,
#  '#keeponlearning': 934,
#  '#girlsinsteam': 935,
#  '--(e)motion': 936,
#  'wanÃ¢Â\x80Â¦': 937,
#  'looser': 938,
#  's:ooo': 939,
#  '#passed': 940,
#  'halsey': 941,
#  '#healing!!': 942,
#  'proud!!!': 943,
#  '#swansea': 944,
#  'shatter': 945,
#  '[v': 946,
#  '#mar': 947,
#  '#criticsÃ¢Â\x80Â¦Ã¢Â\x80Â¦': 948,
#  'ivaromanska': 949,
#  '2month': 950,
#  '#shesabeaut': 951,
#  'af.': 952,
#  '#random': 953,
#  'defund': 954,
#  '#buyhairhere': 955,
#  'airmen': 956,
#  'paner': 957,
#  'Ã°Â\x9fÂ\x98Â\x81Ã°Â\x9fÂ\x98Â\x81Ã°Â\x9fÂ\x91Â\x8fÃ°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x91Â\x8fÃ°Â\x9fÂ\x8fÂ»': 958,
#  'marginalized': 959,
#  '#bud': 960,
#  'troll': 961,
#  '#vans': 962,
#  '#gonnabemarried': 963,
#  '#99c/Ã¢Â\x80Â¦': 964,
#  '#thrills': 965,
#  'project!': 966,
#  '#youthday2016': 967,
#  'day,so': 968,
#  'foreverÃ°Â\x9fÂ\x92Â\x95': 969,
#  'conceded': 970,
#  'bute': 971,
#  '#friedrichlistÃ¢Â\x80Â¦': 972,
#  '#family!': 973,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x91Â¶Ã°Â\x9fÂ\x8fÂ¾': 974,
#  'liv': 975,
#  'bridges': 976,
#  '#branding': 977,
#  'carson': 978,
#  '#resign': 979,
#  'errythang': 980,
#  'tower.': 981,
#  '#magictea': 982,
#  'upod': 983,
#  '2001!': 984,
#  'watched': 985,
#  'spo,': 986,
#  'roses!': 987,
#  'vital': 988,
#  '#introve,': 989,
#  '#manspreading': 990,
#  'seizure': 991,
#  'contain': 992,
#  '#idiopathic': 993,
#  'consulted': 994,
#  'shall': 995,
#  '#xx1': 996,
#  'ent..': 997,
#  'Ã°Â\x9fÂ\x98Â±Ã°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x92Â°Ã°Â\x9fÂ\x91Â\x8d#training': 998,
#  'jihadist': 999,
#  ...}

# %%
layer_0 = np.zeros((1,vocab_size))
layer_0.shape
# Out:
# (1, 67168)

# %%
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'meee!!!!': 1,
#  '#bangsean': 2,
#  'camden!...': 3,
#  '#cjreform?': 4,
#  'gen.': 5,
#  'clothes,': 6,
#  '#singalong': 7,
#  'post]': 8,
#  '#josie': 9,
#  '#justkeepswimming': 10,
#  'russia': 11,
#  'rabid': 12,
#  '#goodtv': 13,
#  'equipment.': 14,
#  '#blackmagic': 15,
#  'buraa': 16,
#  'conÃ¢Â\x80Â¦': 17,
#  '57': 18,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x91Â«': 19,
#  '#shame': 20,
#  'kickstaer.': 21,
#  '#socloseyetsofar': 22,
#  'legacy!!!': 23,
#  'design.': 24,
#  'digging': 25,
#  'Ã°Â\x9fÂ\x98Â¢Ã°Â\x9fÂ\x98Â¢Ã°Â\x9fÂ\x8dÂ´Ã¢Â\x9dÂ\x8c': 26,
#  '#lostinthemuseum2016': 27,
#  'ill,': 28,
#  '#rother': 29,
#  'know,': 30,
#  'Ã¢Â\x9eÂª': 31,
#  'Ã¢Â\x98ÂºÃ°Â\x9fÂ\x99Â\x86': 32,
#  '#fitnesscentre': 33,
#  '#zucchini': 34,
#  '#edenandjaysbestday': 35,
#  '#sounda': 36,
#  'challenge!': 37,
#  '#bakery': 38,
#  'Ã°Â\x9fÂ\x8dÂ\x81Ã¢Â\x9cÂ\x88Ã¯Â¸Â\x8fgreat': 39,
#  '#paylife': 40,
#  '#rosie': 41,
#  '#staystrong': 42,
#  'stiff': 43,
#  'peyton': 44,
#  'offer.': 45,
#  '#violence!': 46,
#  '-10/06/16': 47,
#  'dawned': 48,
#  'abby': 49,
#  'dying': 50,
#  '#timbuon': 51,
#  'Ã¢Â\x80Â\x9cgood': 52,
#  '73.67%...': 53,
#  '#chillin': 54,
#  'realÃ¢Â\x80Â¦': 55,
#  'jockey': 56,
#  'before-bed': 57,
#  '&amp;dream': 58,
#  'shyt.': 59,
#  '#celebspot': 60,
#  ',Ã¢Â\x80Â¦': 61,
#  'google': 62,
#  'legendary': 63,
#  'Ã°Â\x9fÂ\x8dÂ\x94Ã°Â\x9fÂ\x98Â\x81': 64,
#  'ibiza.': 65,
#  '#psyched.': 66,
#  'day!tuesdays': 67,
#  'herÃ¢Â\x80Â¦': 68,
#  'indie': 69,
#  '#poppetmaster': 70,
#  '#bigeventforme': 71,
#  '#resolution': 72,
#  '#kohlisoonÃ\x82Â\xa0': 73,
#  'genocide?': 74,
#  'friendÃ°Â\x9fÂ\x92Â\x85Ã°Â\x9fÂ\x8fÂ¼': 75,
#  'faiths,Ã¢Â\x80Â¦': 76,
#  'friggin': 77,
#  '#colorsay': 78,
#  'oak': 79,
#  'brisk_and_ham-on_and_on_(slipmatt_remix)-(ng010)-web-1998-ukhx_int': 80,
#  '1:80': 81,
#  '1.4440': 82,
#  '32': 83,
#  'florida': 84,
#  '#lovetotravelalloveheworldÃ¢Â\x80Â¦': 85,
#  'peeling': 86,
#  'heat."': 87,
#  'irelands': 88,
#  'negative': 89,
#  '#greatpeople': 90,
#  'dj_ham-new_style__your_love-(ng018)-web-1998-ukhx_int': 91,
#  'bridget': 92,
#  'Ã°Â\x9fÂ\x98Â³Ã°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x8cÂ¸': 93,
#  '#themaineaudition': 94,
#  'Ã°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x99Â\x8f': 95,
#  '#fearlessÃ¢Â\x80Â¦': 96,
#  '#ptxworldtour': 97,
#  'nose': 98,
#  'letterkenny': 99,
#  '#smilepowerday!': 100,
#  "wife's": 101,
#  'listing': 102,
#  '#unchaed': 103,
#  "pep's": 104,
#  'holder': 105,
#  '#bernielostme': 106,
#  'sunrise': 107,
#  '#amwriting': 108,
#  '#stylistic#': 109,
#  '6': 110,
#  '#songwriter.': 111,
#  'chuckled': 112,
#  '#navyyard': 113,
#  'heskin': 114,
#  'rebeccas': 115,
#  "dogmeetsfamily's": 116,
#  "india's": 117,
#  'fw': 118,
#  'manzini': 119,
#  'pumped!': 120,
#  'banking': 121,
#  'fascists': 122,
#  'royale': 123,
#  '#bestabiamo': 124,
#  'sack': 125,
#  'not?"': 126,
#  '13hrs': 127,
#  'Ã°Â\x9fÂ\x92Â\x95Ã°Â\x9fÂ\x92Â\x9e': 128,
#  '#truthseekers': 129,
#  '#sundayfun': 130,
#  '#whererefreshingbegins': 131,
#  '#thestarspangledbanner': 132,
#  '#gbe': 133,
#  '#hamr': 134,
#  '"mini': 135,
#  'place???': 136,
#  'assist': 137,
#  '30': 138,
#  'campeon': 139,
#  '#5years': 140,
#  'Ã°Â\x9fÂ\x91Â\x8dÃ°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x98Â\x8e': 141,
#  'bating': 142,
#  "#dad's/": 143,
#  "'star": 144,
#  'ideal.': 145,
#  'Ã°Â\x9fÂ\x8eÂ¤Ã°Â\x9fÂ\x8eÂµÃ°Â\x9fÂ\x8eÂ¶Ã°Â\x9fÂ\x8eÂ¸': 146,
#  '#22': 147,
#  'meÃ¢Â\x9dÂ¤Ã¯Â¸Â\x8f': 148,
#  '#nickjonas': 149,
#  'minimum': 150,
#  'Ã°Â\x9fÂ\x8dÂ\x95': 151,
#  '-yeehaaaw-': 152,
#  'some!!!': 153,
#  '#ecto1': 154,
#  '#fact': 155,
#  '#lbgt': 156,
#  '#deceitful': 157,
#  '#mentors': 158,
#  'economy.': 159,
#  'caption!': 160,
#  '#grandmothers': 161,
#  'stain': 162,
#  'a?': 163,
#  '(did': 164,
#  '#love#instadaily': 165,
#  'asylum.': 166,
#  'Ã°Â\x9fÂ\x98Â\x99Ã°Â\x9fÂ\x91Â\x8c': 167,
#  '#salary': 168,
#  'nicole.': 169,
#  'loversÃ¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x91Â\x91Ã°Â\x9fÂ\x91Â¸Ã°Â\x9fÂ\x8fÂ»': 170,
#  '#flowerofjoy': 171,
#  '#skinny': 172,
#  'Ã°Â\x9fÂ\x98Â\x83Ã¢Â\x9cÂ\x88Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x8eÂ\x89Ã¢Â\x98Â\x80Ã¯Â¸Â\x8f': 173,
#  'teaser!': 174,
#  '#interview': 175,
#  'faster': 176,
#  'hysterically?': 177,
#  'at?"': 178,
#  'lo': 179,
#  'islam': 180,
#  'Ã°Â\x9fÂ\x98Â\x92Ã°Â\x9fÂ\x98Â\x92Ã°Â\x9fÂ\x98Â\x92': 181,
#  'somewhere,': 182,
#  'world.': 183,
#  '#vaÃ¢Â\x80Â¦': 184,
#  'puffs': 185,
#  '#byebye': 186,
#  'complete!!': 187,
#  '#ilovepaint': 188,
#  'clientele': 189,
#  '#fatherson#': 190,
#  'turns': 191,
#  'concerned': 192,
#  'paner+i': 193,
#  'crow': 194,
#  '#goskate': 195,
#  'stone!!!': 196,
#  '#snorkeling': 197,
#  'someÃ°Â\x9fÂ\x92Â\x8b': 198,
#  '#ishir': 199,
#  '#baahubali': 200,
#  '#delhi': 201,
#  'generations': 202,
#  '#britishweathersucks': 203,
#  '#inaspanof': 204,
#  'beg': 205,
#  '#ss16': 206,
#  'extensions': 207,
#  'stint': 208,
#  'california': 209,
#  'us!': 210,
#  '#photooftoday': 211,
#  'discol': 212,
#  'student!': 213,
#  '#goodsunday': 214,
#  'whitey': 215,
#  '#overdose': 216,
#  'fan?': 217,
#  '#youthday': 218,
#  'unbelievable': 219,
#  '#ramodmalaka': 220,
#  'over-rode': 221,
#  '#rec405': 222,
#  'Ã°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x92Â\x8b': 223,
#  'releases': 224,
#  '#vbs2016': 225,
#  'spot': 226,
#  'but,': 227,
#  '#smilers': 228,
#  '#hedgehog': 229,
#  'smiling,': 230,
#  'agent': 231,
#  'guns?': 232,
#  'selah': 233,
#  '6p': 234,
#  'oprah,': 235,
#  'headlines!!!!': 236,
#  'tickets:': 237,
#  '#conveibleÃ¢Â\x80Â¦': 238,
#  'mints': 239,
#  'kana??': 240,
#  '#flip': 241,
#  '#psa': 242,
#  '#bars': 243,
#  'puzzle': 244,
#  'teach': 245,
#  'xoxo': 246,
#  'graffiti': 247,
#  'trouble.': 248,
#  'ensure': 249,
#  'while': 250,
#  '#tunbridgewells': 251,
#  '#loveÃ°Â\x9fÂ\x91Â¼': 252,
#  '#wwefi': 253,
#  'jaggi': 254,
#  'app:': 255,
#  '#kitten#keith#8weeks#waitinggame': 256,
#  '#show...': 257,
#  'Ã°Â\x9fÂ\x92Â\x8bÃ°Â\x9fÂ\x98Â\x8bÃ°Â\x9fÂ\x98Â\x85': 258,
#  '46': 259,
#  'cut,': 260,
#  'much,much': 261,
#  'delays': 262,
#  'drop,': 263,
#  'retimed': 264,
#  '#durdledoor': 265,
#  'take?': 266,
#  'top!': 267,
#  '#tech': 268,
#  'dog...is': 269,
#  'trafficking': 270,
#  '#ecofriendly': 271,
#  '#bogum616day': 272,
#  '#greattracks': 273,
#  '#businessgoals': 274,
#  'unfiltered': 275,
#  'fears.': 276,
#  '#universe': 277,
#  '#behdayÃ¢Â\x80Â¦': 278,
#  '2:30am': 279,
#  'imyyyyÃ°Â\x9fÂ\x98Â\x98': 280,
#  '#nationalvegetableday': 281,
#  '#beseen': 282,
#  'ootnÃ°Â\x9fÂ\x92Â\x81Ã°Â\x9fÂ\x8fÂ»#nightout': 283,
#  'argh!': 284,
#  'proved': 285,
#  '#stream!': 286,
#  'sylvia': 287,
#  'werdz?': 288,
#  '#jews.': 289,
#  'Ã³Â¾Â\x81Â\x98Ã³Â¾Â\x81Â\x98Ã³Â¾Â\x81Â\x98': 290,
#  '#muskoka': 291,
#  '#celticpoetry': 292,
#  'suicides.': 293,
#  'form': 294,
#  '#dancemoms3': 295,
#  'Ã°Â\x9fÂ\x87Â¨Ã°Â\x9fÂ\x87Â¦Ã°Â\x9fÂ\x87Â¨Ã°Â\x9fÂ\x87Â¦Ã°Â\x9fÂ\x87Â¨Ã°Â\x9fÂ\x87Â¦': 296,
#  'wise...Ã°Â\x9fÂ\x98Â\x8e': 297,
#  '#pug': 298,
#  'store.': 299,
#  'hindus': 300,
#  'victims!': 301,
#  '#dahlia': 302,
#  '#fitnessfriday': 303,
#  'somalia': 304,
#  '#terrabitesfood': 305,
#  '#booze': 306,
#  'holy': 307,
#  '#effluent': 308,
#  'race...': 309,
#  '#tedatibm': 310,
#  'branch.': 311,
#  'bihdayswayÃ°Â\x9fÂ\x92Â\x99': 312,
#  '#do': 313,
#  '#scaredfohefuture': 314,
#  'Ã°Â\x9fÂ\x91Â°Ã°Â\x9fÂ\x91Â°Ã°Â\x9fÂ\x91Â°Ã°Â\x9fÂ\x91Â«Ã°Â\x9fÂ\x91Â«': 315,
#  "fiddler's": 316,
#  'deliveries': 317,
#  '#byecar': 318,
#  'played.': 319,
#  'trashing': 320,
#  '#makesomeonesmiletoday': 321,
#  'recession': 322,
#  'face"': 323,
#  'shops.': 324,
#  'riddance!': 325,
#  'reciprocated.': 326,
#  'admirer': 327,
#  'trump.': 328,
#  '#bump': 329,
#  '#cat': 330,
#  '#grayneedstogo': 331,
#  'indefensible.': 332,
#  'governor:': 333,
#  '#sesekali': 334,
#  'fohcoming': 335,
#  '#unbiosibs': 336,
#  'third': 337,
#  '#justice': 338,
#  '#westboro': 339,
#  'te': 340,
#  '("': 341,
#  '&lt;---my': 342,
#  'streetÃ¢Â\x80Â¦': 343,
#  'shane': 344,
#  'students.': 345,
#  '#bangerztour': 346,
#  '#weapons': 347,
#  'please!!!': 348,
#  'loathsome': 349,
#  'district': 350,
#  'Ã°Â\x9fÂ\x91Â\x8fÃ°Â\x9fÂ\x8fÂ¼Ã°Â\x9fÂ\x98Â\x82': 351,
#  'along.': 352,
#  'awwww...': 353,
#  '#produce101teachers': 354,
#  'tumor': 355,
#  '#cantkeepmymouthshut': 356,
#  'then,': 357,
#  'awarded': 358,
#  'nvr': 359,
#  '#wrath,': 360,
#  '#recording!': 361,
#  'Ã°Â\x9fÂ\x91Â\x86link': 362,
#  'happy..': 363,
#  'lawyer:': 364,
#  '#runnerslife': 365,
#  'speech.': 366,
#  'Ã°Â\x9fÂ¤Â\x93Ã°Â\x9fÂ\x92Â\x8b': 367,
#  'grumpy': 368,
#  'chidi': 369,
#  'lead...': 370,
#  'stranger': 371,
#  'Ã°Â\x9fÂ\x98Â\x8cÃ°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x98Â\x8a': 372,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fu': 373,
#  '#ledger,': 374,
#  'savoryandsweetfood': 375,
#  '#shamelessly': 376,
#  '#functionsÃ¢Â\x80Â¦': 377,
#  'healthcaÃ¢Â\x80Â¦': 378,
#  '#dignitas': 379,
#  '#actorlife': 380,
#  'buckley': 381,
#  'sure?': 382,
#  '#merica': 383,
#  '5pm': 384,
#  '#yikez': 385,
#  'compliments': 386,
#  'muslims!': 387,
#  'blm': 388,
#  'mfc,': 389,
#  '#beautyblogger': 390,
#  'asking.': 391,
#  '#hoppy': 392,
#  '#failure?': 393,
#  'liked^^': 394,
#  'tomorrow)': 395,
#  'kyrie,': 396,
#  'gt': 397,
#  'deeply!!!': 398,
#  'manning...': 399,
#  '#lifeatihg': 400,
#  'frighteningly': 401,
#  'think...we': 402,
#  'herself': 403,
#  'e3': 404,
#  'business': 405,
#  'ndigbo': 406,
#  '#streetmusica': 407,
#  'fire!': 408,
#  'bday!': 409,
#  'Ã°Â\x9fÂ\x98Â\x8dÃ°Â\x9fÂ\x98Â\x8dÃ°Â\x9fÂ\x98Â\x84Ã°Â\x9fÂ\x92Â\x9c': 410,
#  '#beardsofinstagramÃ¢Â\x80Â¦': 411,
#  '#harassment,': 412,
#  '#beoplay': 413,
#  'remodeling': 414,
#  '#poes': 415,
#  '#inloveÃ¢Â\x80Â¦': 416,
#  '#keepenjoy': 417,
#  'kitties.': 418,
#  '#stayblessed': 419,
#  '-some-': 420,
#  'bsÃ°Â\x9fÂ\x99Â\x84': 421,
#  '(mainly': 422,
#  '#momentos': 423,
#  '#lincsconnect': 424,
#  'nandita': 425,
#  'champagne': 426,
#  '#dudes': 427,
#  'guilbe': 428,
#  'pub!': 429,
#  'procreate!': 430,
#  '#january': 431,
#  'mugs': 432,
#  '#bihday': 433,
#  'silverado!': 434,
#  '#metalheadÃ¢Â\x80Â¦': 435,
#  '"nope"': 436,
#  'referring': 437,
#  'exploring': 438,
#  'equals....Ã\x82Â\xa0a': 439,
#  "'tail'": 440,
#  '#aupair#aupairlife': 441,
#  '#baycityrollers': 442,
#  'Ã¢Â\x98Â\x80Ã°Â\x9fÂ\x8cÂ\x9fÃ¢Â\x98Â\x80': 443,
#  'forecasts': 444,
#  'alyssa': 445,
#  'ignored....': 446,
#  'comics:': 447,
#  '#corporatecharitychampionoftheyear': 448,
#  'Ã¢Â\x99Â¥min': 449,
#  '#fatty.': 450,
#  '#british': 451,
#  'corny': 452,
#  'being.Ã¢Â\x80Â\x9d': 453,
#  'tenure': 454,
#  '#revisions': 455,
#  'tin': 456,
#  '#mondayblues': 457,
#  '#followers!': 458,
#  '#amarinder': 459,
#  'boys!': 460,
#  '#glasto': 461,
#  'chingola': 462,
#  'crown': 463,
#  'vai': 464,
#  'muad.': 465,
#  '#farm-dogs': 466,
#  '#damonsajnani': 467,
#  '#theedge': 468,
#  '#needbreakfastÃ¢Â\x80Â¦': 469,
#  'Ã°Â\x9fÂ\x92Â¡Ã°Â\x9fÂ\x91Â\x89Ã¢Â\x80Â¦': 470,
#  'chic': 471,
#  'Ã¢Â\x9cÂ¨Ã°Â\x9fÂ\x92Â\xad': 472,
#  '#onmyway': 473,
#  'energized.': 474,
#  'gmorn!Ã°Â\x9fÂ\x8cÂ\x9eÃ°Â\x9fÂ\x90Â¯Ã°Â\x9fÂ\x92Â\x9b': 475,
#  '#yehtut': 476,
#  "paladino's": 477,
#  'skrillex': 478,
#  '#manor': 479,
#  '#dribbble': 480,
#  'greedy': 481,
#  '#nextstep': 482,
#  '#conquercancer': 483,
#  'Ã°Â\x9fÂ\x91Â\x8c#airpo': 484,
#  '#namibianpoet': 485,
#  'late...too': 486,
#  '#haÃ¢Â\x80Â¦': 487,
#  '#grimmie': 488,
#  'misogyny': 489,
#  'mins': 490,
#  '(#mw2)': 491,
#  '#walkingÃ¢Â\x80Â¦': 492,
#  'clio': 493,
#  '350s': 494,
#  '#Ã£Â\x83Â¡Ã£Â\x83ÂªÃ£Â\x83Â¼Ã£Â\x83Â\x9dÃ£Â\x83Â\x94Ã£Â\x83Â³Ã£Â\x82Âº': 495,
#  'Ã°Â\x9fÂ\x8cÂ\x8eÃ°Â\x9fÂ\x8cÂ·': 496,
#  'soooooooooo': 497,
#  'paies': 498,
#  'midday': 499,
#  'dhin': 500,
#  '229': 501,
#  'bodega': 502,
#  '#confidence,': 503,
#  'tim': 504,
#  'nature!': 505,
#  '#discipline': 506,
#  'game!': 507,
#  'weeheeeee~': 508,
#  '#ski': 509,
#  'wrendavis': 510,
#  '#trumpdallas': 511,
#  'skype:': 512,
#  '#faithful': 513,
#  'sub,': 514,
#  "u're": 515,
#  'clap': 516,
#  'bunch.': 517,
#  'evenings.': 518,
#  '#unbiosibsÃ¢Â\x80Â¦': 519,
#  'erich': 520,
#  'long...': 521,
#  '18]': 522,
#  '#focusonthegood': 523,
#  '#joyas': 524,
#  '#actors': 525,
#  '#denim': 526,
#  '#dongiovanni': 527,
#  'parin': 528,
#  'more:': 529,
#  '#selfie': 530,
#  'tent.': 531,
#  'pressed.': 532,
#  'tue.': 533,
#  'maggie': 534,
#  '#dahvader': 535,
#  'does.': 536,
#  '2/2': 537,
#  '#libcrib': 538,
#  'eerie': 539,
#  '#deletetweets': 540,
#  'legends': 541,
#  'waiting...all': 542,
#  '#cutequotes': 543,
#  'off!!!!!': 544,
#  'Ã°Â\x9fÂ\x99Â\x8fÃ°Â\x9fÂ\x8fÂ½Ã°Â\x9fÂ\x92Â\x95': 545,
#  'memoire': 546,
#  'lls': 547,
#  'flamengo': 548,
#  '#pllseason7': 549,
#  '#couple': 550,
#  '#careerrocks': 551,
#  'yoh': 552,
#  '#gettingready': 553,
#  '#silveÃ¢Â\x80Â¦': 554,
#  '#19days': 555,
#  '#nowplaying': 556,
#  '#highpeaks': 557,
#  'value!': 558,
#  '#digitalrevolution': 559,
#  'ngos': 560,
#  '#paradox': 561,
#  '#youcandothis': 562,
#  '#shihtzu': 563,
#  'project.': 564,
#  'awesome-day?': 565,
#  '#dailypoll': 566,
#  'Ã°Â\x9fÂ\x8cÂ\x90': 567,
#  'freed': 568,
#  '#nintendoe3': 569,
#  '#frump!': 570,
#  'mk': 571,
#  '#pbcrave': 572,
#  '#torbayairshow': 573,
#  'joyful.': 574,
#  '21.': 575,
#  '#tiredashell': 576,
#  '#systemicracism': 577,
#  '#fashionshows#bridalweekend': 578,
#  'sold': 579,
#  'netflix': 580,
#  'he...': 581,
#  'journlst': 582,
#  '#hens': 583,
#  'devalue': 584,
#  '#cosplay': 585,
#  'sphere!': 586,
#  'destination,': 587,
#  'hybrid': 588,
#  'dacks!': 589,
#  'thirst': 590,
#  'rising!': 591,
#  '#cielphantomhive': 592,
#  '55th': 593,
#  'hillary,': 594,
#  '#bigpharma': 595,
#  'dad...Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8f': 596,
#  '#readÃ¢Â\x80Â¦': 597,
#  '#pennsylvania': 598,
#  'rearing': 599,
#  "noah's": 600,
#  'aed': 601,
#  '#clintonforprison': 602,
#  'tackle': 603,
#  'Ã°Â\x9fÂ\x90Â¶Ã°Â\x9fÂ¤Â\x98Ã°Â\x9fÂ\x8fÂ¼': 604,
#  'babe"': 605,
#  '#shemad': 606,
#  '9919': 607,
#  '#july': 608,
#  '#rosa': 609,
#  '#monies': 610,
#  '#orangeisthenewblack': 611,
#  'patronizing': 612,
#  '#glorious': 613,
#  '#maari': 614,
#  '#now,': 615,
#  '-.-': 616,
#  '#Ã§Â\x8cÂ«': 617,
#  '#harleydavidson': 618,
#  'rough': 619,
#  '#darling': 620,
#  '#ramshackle': 621,
#  '#mummybloggers': 622,
#  'sicker': 623,
#  'Ã°Â\x9fÂ\x98Â\x8eÃ°Â\x9fÂ\x98Â\x8eÃ°Â\x9fÂ\x98Â\x8e': 624,
#  'biryhday': 625,
#  'instinct,': 626,
#  'mullahs': 627,
#  '#sunny': 628,
#  'huh...': 629,
#  'end..........': 630,
#  '#healthyfood': 631,
#  '#feminist,': 632,
#  '#ontheredcarpet': 633,
#  '#regrann': 634,
#  'y': 635,
#  'daves': 636,
#  '#wyonnaearp': 637,
#  'while.': 638,
#  'barbican': 639,
#  'gran': 640,
#  '#manilow': 641,
#  '#bringiton': 642,
#  'communism.': 643,
#  'obligation.': 644,
#  '#steve': 645,
#  '#makelife': 646,
#  'whether': 647,
#  '#fragrantjewels': 648,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x8eÂ¯': 649,
#  '#keepgoing': 650,
#  '#flagfriday': 651,
#  ':(': 652,
#  'ave.': 653,
#  'land.': 654,
#  '#clubtuas': 655,
#  'revised': 656,
#  'Ã¢Â\x9aÂ¡who': 657,
#  '#genting': 658,
#  '#lifesaver': 659,
#  'whoop,': 660,
#  'Ã°Â\x9fÂ\x8cÂ¸Ã°Â\x9fÂ\x8eÂ¤xx': 661,
#  'gimme:': 662,
#  'multiple': 663,
#  'sent': 664,
#  'ruins': 665,
#  'approved,': 666,
#  '#wbencconf': 667,
#  '#cherry': 668,
#  'placed!': 669,
#  '#satinderkariha': 670,
#  'embarrassing': 671,
#  'life....': 672,
#  'ww,': 673,
#  '#livinÃ¢Â\x80Â¦': 674,
#  "mark's": 675,
#  '#timwise': 676,
#  '#mfact': 677,
#  'cultures': 678,
#  'Ã°Â\x9fÂ\x98Â¶': 679,
#  '#presentmood': 680,
#  '#paramore': 681,
#  '#anotherwomanwedding': 682,
#  'itz': 683,
#  '#prose': 684,
#  'Ã°Â\x9fÂ\x98Â\x80Ã°Â\x9fÂ\x98Â\x80Ã°Â\x9fÂ\x98Â\x80Ã°Â\x9fÂ\x98Â\x80': 685,
#  '(hd': 686,
#  'mockery': 687,
#  '#yummy': 688,
#  '"your': 689,
#  'jo': 690,
#  'bigot?': 691,
#  '(ken)': 692,
#  'creator': 693,
#  'connection.': 694,
#  '#gmspastorsretreat2016': 695,
#  'rising': 696,
#  '#hhwear': 697,
#  'successful,': 698,
#  'monthly': 699,
#  '#dancers': 700,
#  'points': 701,
#  '#intolerance': 702,
#  'sense': 703,
#  '#saynotodrugs': 704,
#  'siste': 705,
#  'hyena': 706,
#  'Ã°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x93Â¦Ã°Â\x9fÂ\x9aÂ\x9a': 707,
#  'Ã°Â\x9fÂ\x92Â\x9bÃ¢Â\x98Â\x80Ã¯Â¸Â\x8f': 708,
#  '#bleedpurple': 709,
#  '#libeypr': 710,
#  'aud/nzd': 711,
#  '#firsttime': 712,
#  '#singsnap': 713,
#  '#allday': 714,
#  'weather': 715,
#  'Ã¯Â¼Â\x83cute': 716,
#  'alapoet:': 717,
#  'c2c': 718,
#  '#indiegame': 719,
#  '&amp;thankful': 720,
#  'squiin': 721,
#  'Ã°Â\x9fÂ\x8cÂ\x9eÃ°Â\x9fÂ\x8eÂªÃ°Â\x9fÂ\x8cÂ³Ã°Â\x9fÂ\x8cÂ¼Ã°Â\x9fÂ\x8dÂ\x96Ã°Â\x9fÂ\x8dÂ³Ã°Â\x9fÂ\x8cÂ¶Ã°Â\x9fÂ\x8cÂ½Ã°Â\x9fÂ\x8dÂ\x99': 722,
#  '#newyorkÃ¢Â\x80Â¦': 723,
#  'theater': 724,
#  'werewolf': 725,
#  'Ã°Â\x9fÂ\x98Â\x81Ã°Â\x9fÂ\x98Â\x9cÃ°Â\x9fÂ\x98Â\x86Ã°Â\x9fÂ\x98Â\x85#me#selfie#today': 726,
#  'precious..': 727,
#  'inhabitant.': 728,
#  'play': 729,
#  'colors!': 730,
#  '#thehappinets': 731,
#  'hello.': 732,
#  '#betrayal': 733,
#  '#3bookstogo': 734,
#  'natin': 735,
#  'leftover': 736,
#  'thursday!Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ¾Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ¾Ã°Â\x9fÂ\x99Â\x8cÃ°Â\x9fÂ\x8fÂ¾': 737,
#  'critiquing': 738,
#  'prettiest': 739,
#  '#unpresidented': 740,
#  'thrilling.': 741,
#  'bcoz': 742,
#  '#rivieramaya': 743,
#  'oppounities:': 744,
#  'common,': 745,
#  '#dadnme': 746,
#  'baby!!': 747,
#  'negative...': 748,
#  'ish': 749,
#  '#fullnessÃ¢Â\x80Â¦': 750,
#  '#summeimeflowers': 751,
#  'heas"': 752,
#  '*this*': 753,
#  '#25': 754,
#  'Ã¢Â\x99Â¥rap': 755,
#  '#bihdaynightout': 756,
#  'coopting': 757,
#  'producers': 758,
#  'thanking': 759,
#  '#stateofwomen': 760,
#  'preview:': 761,
#  'blah': 762,
#  'pvp': 763,
#  '#lovecamping': 764,
#  '6%': 765,
#  '#airconditioner': 766,
#  "happyfather'sdayÃ°Â\x9fÂ\x91Â¨Ã°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x8cÂ¹": 767,
#  'wish...': 768,
#  '#msc': 769,
#  'mayuko!!!': 770,
#  'mediocre': 771,
#  'enteain': 772,
#  'won!!!!!': 773,
#  'fallon': 774,
#  '#grandfinal': 775,
#  'veterans.': 776,
#  "up'": 777,
#  '#policetraining': 778,
#  'tomato': 779,
#  'waterloo.': 780,
#  '"elizabeth': 781,
#  '#paners': 782,
#  'dancing!': 783,
#  'sureÃ¢Â\x80Â¦': 784,
#  'lock': 785,
#  '#travelpics': 786,
#  'anniversary!!Ã°Â\x9fÂ\x92Â\x90Ã°Â\x9fÂ\x8eÂ\x82Ã°Â\x9fÂ\x98Â\x98Ã°Â\x9fÂ\x8eÂ\x81Ã°Â\x9fÂ\x8eÂ\x81': 787,
#  'cup,': 788,
#  'swim!!': 789,
#  'nobodies': 790,
#  '#jokes,': 791,
#  'ashton': 792,
#  '#runnerdad': 793,
#  '#offend': 794,
#  'wednesday...': 795,
#  '27th...our': 796,
#  'controlled': 797,
#  'jessiestyman': 798,
#  'adams': 799,
#  '(dramatic,': 800,
#  'gloucestershire': 801,
#  '#refleÃ¢Â\x80Â¦': 802,
#  'first!)': 803,
#  '#sjws': 804,
#  '#goodtimeswithgoÃ¢Â\x80Â¦': 805,
#  'primary.@user': 806,
#  "shitheads'": 807,
#  '#erenromasadiyor': 808,
#  '#farrahangphotography': 809,
#  'fes.': 810,
#  'Ã°Â\x9fÂ\x91Â\x89Ã°Â\x9fÂ\x8fÂ»#pretending#to#be': 811,
#  '#farewell': 812,
#  'pills': 813,
#  'really!': 814,
#  '#instaviÃ\x83Â±a': 815,
#  'germany,': 816,
#  '#hamiltonmusical': 817,
#  'happened.': 818,
#  '#dead': 819,
#  'refined.#i_am': 820,
#  '#lollipop': 821,
#  'does,': 822,
#  "'devastating'": 823,
#  "he'll": 824,
#  'appear!!': 825,
#  '#marvelstheavengers': 826,
#  'chambers': 827,
#  '#Ã¬Â\x83Â\x9dÃ¬Â\x9dÂ¼Ã£Â\x85Â\x8aÃ£Â\x85Â\x8e': 828,
#  '#whiteamerica': 829,
#  'today...': 830,
#  'internationals': 831,
#  '!Ã°Â\x9fÂ\x92Â¤Ã°Â\x9fÂ\x92Â¤Ã°Â\x9fÂ\x97Â\x9dÃ°Â\x9fÂ\x97Â\x9dÃ°Â\x9fÂ\x8fÂ\xa0Ã°Â\x9fÂ\x8fÂ¡Ã°Â\x9fÂ\x8fÂ¡Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8f': 832,
#  '#populism': 833,
#  'begging...': 834,
#  '#newstyles': 835,
#  'shawnee': 836,
#  '#olives': 837,
#  'addresses': 838,
#  'prevented': 839,
#  'Ã°Â\x9fÂ\x98Â\x8bÃ°Â\x9fÂ\x92Â\x95Ã°Â\x9fÂ\x92Â\x95Ã°Â\x9fÂ\x92Â\x95': 840,
#  '#enoughisenough': 841,
#  '#castingcall': 842,
#  'yoakam': 843,
#  'lol!!!': 844,
#  'promotions?': 845,
#  'almost': 846,
#  'professionals': 847,
#  '#hfd': 848,
#  'all,': 849,
#  '"Ã¢Â\x80Â¦': 850,
#  '#unreformable': 851,
#  '#tabby': 852,
#  '#thanksgodÃ°Â\x9fÂ\x92Â\x99': 853,
#  'racism.': 854,
#  'youuu!!!!': 855,
#  'sucked': 856,
#  'zone,': 857,
#  '#employment': 858,
#  '#alaba': 859,
#  'determined': 860,
#  '#barney': 861,
#  '#nature##sea': 862,
#  '#bettehan': 863,
#  'oxygen': 864,
#  '#giftideas': 865,
#  'him..': 866,
#  '#mikado': 867,
#  'rigged/pathetic': 868,
#  'pfft.': 869,
#  'Ã¢Â\x98ÂºÃ¯Â¸Â\x8fÃ°Â\x9fÂ\x93Â\x9a': 870,
#  '#inawe': 871,
#  '#thebachelorette': 872,
#  'keshi,': 873,
#  '#litfest': 874,
#  'newsÃ°Â\x9fÂ\x98Â\x84Ã°Â\x9fÂ\x98Â\x84': 875,
#  '#ugly': 876,
#  'absÃ°Â\x9fÂ\x94Â¥': 877,
#  'punjab.': 878,
#  '#donteventryit': 879,
#  '13.8': 880,
#  'tomoro': 881,
#  '#trade': 882,
#  '#shape': 883,
#  'Ã\x82Â\xa0uniform': 884,
#  '#shanklin': 885,
#  'interesting......': 886,
#  'russell.beckwith': 887,
#  'midle': 888,
#  'respect': 889,
#  'needing': 890,
#  '#nbafinals2016': 891,
#  '#tos': 892,
#  'faves': 893,
#  '#ancestral': 894,
#  '#idc': 895,
#  'Ã¢Â\x98ÂºÃ¯Â¸Â\x8fÃ°Â\x9fÂ\x98Â\x8d.': 896,
#  'berke': 897,
#  '(Ã\x82Â¯`Ã¢Â\x99Â¥Ã\x82Â´Ã\x82Â¯)Ã¢Â\x95Â\x90&gt;': 898,
#  '#besuccessful': 899,
#  'be': 900,
#  'embodiment': 901,
#  'be4': 902,
#  '$3.5': 903,
#  '#buildings': 904,
#  '#cameraÃ¢Â\x80Â¦': 905,
#  'well;': 906,
#  'shit,': 907,
#  'pnc': 908,
#  '#djvarra': 909,
#  'rope': 910,
#  'fulfilling': 911,
#  'cancellations': 912,
#  'datas.': 913,
#  '#ofcourse': 914,
#  'conniving,': 915,
#  'Ã¢Â\x9cÂ\x8d': 916,
#  ';(': 917,
#  '#fantasticlies': 918,
#  'magnum': 919,
#  'google-': 920,
#  "imm'ts": 921,
#  '#getwhatyouwant': 922,
#  '#seals': 923,
#  'holiday,': 924,
#  '#flowÃ°Â\x9fÂ\x8dÂ·Ã°Â\x9fÂ\x92Â\x93#friends': 925,
#  'kennel': 926,
#  'herÃ°Â\x9fÂ\x98Â\x82#mylittlepony': 927,
#  '#tried': 928,
#  '#themoodcards': 929,
#  'perspective': 930,
#  '#duduk': 931,
#  '#whitepaper': 932,
#  '#boiledpeanuts': 933,
#  '#keeponlearning': 934,
#  '#girlsinsteam': 935,
#  '--(e)motion': 936,
#  'wanÃ¢Â\x80Â¦': 937,
#  'looser': 938,
#  's:ooo': 939,
#  '#passed': 940,
#  'halsey': 941,
#  '#healing!!': 942,
#  'proud!!!': 943,
#  '#swansea': 944,
#  'shatter': 945,
#  '[v': 946,
#  '#mar': 947,
#  '#criticsÃ¢Â\x80Â¦Ã¢Â\x80Â¦': 948,
#  'ivaromanska': 949,
#  '2month': 950,
#  '#shesabeaut': 951,
#  'af.': 952,
#  '#random': 953,
#  'defund': 954,
#  '#buyhairhere': 955,
#  'airmen': 956,
#  'paner': 957,
#  'Ã°Â\x9fÂ\x98Â\x81Ã°Â\x9fÂ\x98Â\x81Ã°Â\x9fÂ\x91Â\x8fÃ°Â\x9fÂ\x8fÂ»Ã°Â\x9fÂ\x91Â\x8fÃ°Â\x9fÂ\x8fÂ»': 958,
#  'marginalized': 959,
#  '#bud': 960,
#  'troll': 961,
#  '#vans': 962,
#  '#gonnabemarried': 963,
#  '#99c/Ã¢Â\x80Â¦': 964,
#  '#thrills': 965,
#  'project!': 966,
#  '#youthday2016': 967,
#  'day,so': 968,
#  'foreverÃ°Â\x9fÂ\x92Â\x95': 969,
#  'conceded': 970,
#  'bute': 971,
#  '#friedrichlistÃ¢Â\x80Â¦': 972,
#  '#family!': 973,
#  'Ã¢Â\x9dÂ¤Ã¯Â¸Â\x8fÃ°Â\x9fÂ\x91Â¶Ã°Â\x9fÂ\x8fÂ¾': 974,
#  'liv': 975,
#  'bridges': 976,
#  '#branding': 977,
#  'carson': 978,
#  '#resign': 979,
#  'errythang': 980,
#  'tower.': 981,
#  '#magictea': 982,
#  'upod': 983,
#  '2001!': 984,
#  'watched': 985,
#  'spo,': 986,
#  'roses!': 987,
#  'vital': 988,
#  '#introve,': 989,
#  '#manspreading': 990,
#  'seizure': 991,
#  'contain': 992,
#  '#idiopathic': 993,
#  'consulted': 994,
#  'shall': 995,
#  '#xx1': 996,
#  'ent..': 997,
#  'Ã°Â\x9fÂ\x98Â±Ã°Â\x9fÂ\x98Â\x8aÃ°Â\x9fÂ\x92Â°Ã°Â\x9fÂ\x91Â\x8d#training': 998,
#  'jihadist': 999,
#  ...}

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                ## New for Project 4: changed to set to 1 instead of add 1
                self.layer_0[0][self.word2index[word]] = 1
                
    def get_target_for_label(self,label):
        if(label == 1):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 1):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 0):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def validate(self, testing_reviews):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] )
            
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return 1
        else:
            return 0

# %%
mlp = SentimentNetwork(X,y, learning_rate=0.1)
mlp.train(X,y)
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:7.82% Speed(reviews/sec):309.4 #Correct:2340 #Trained:2501 Training Accuracy:93.5%
# Progress:15.6% Speed(reviews/sec):245.8 #Correct:4678 #Trained:5001 Training Accuracy:93.5%
# Progress:23.4% Speed(reviews/sec):234.7 #Correct:7023 #Trained:7501 Training Accuracy:93.6%
# Progress:31.2% Speed(reviews/sec):227.2 #Correct:9397 #Trained:10001 Training Accuracy:93.9%
# Progress:39.1% Speed(reviews/sec):231.1 #Correct:11763 #Trained:12501 Training Accuracy:94.0%
# Progress:46.9% Speed(reviews/sec):235.0 #Correct:14143 #Trained:15001 Training Accuracy:94.2%
# Progress:54.7% Speed(reviews/sec):238.7 #Correct:16542 #Trained:17501 Training Accuracy:94.5%
# Progress:62.5% Speed(reviews/sec):239.4 #Correct:18915 #Trained:20001 Training Accuracy:94.5%
# Progress:70.3% Speed(reviews/sec):239.9 #Correct:21281 #Trained:22501 Training Accuracy:94.5%
# Progress:78.2% Speed(reviews/sec):236.4 #Correct:23657 #Trained:25001 Training Accuracy:94.6%
# Progress:86.0% Speed(reviews/sec):225.4 #Correct:26035 #Trained:27501 Training Accuracy:94.6%
# Progress:93.8% Speed(reviews/sec):224.4 #Correct:28433 #Trained:30001 Training Accuracy:94.7%
# Progress:99.9% Speed(reviews/sec):224.5 #Correct:30284 #Trained:31962 Training Accuracy:94.7%
